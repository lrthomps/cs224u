# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
import jax
import jax.numpy as jnp
import flax
from flax import linen as nn
import optax

import numpy as np
import pandas as pd
from pandas.api.types import CategoricalDtype

from numpy.lib.stride_tricks import sliding_window_view

# %%
pd.set_option('display.max_rows', 125)
pd.set_option('display.max_columns', 200)

# %%
filename = '~/Downloads/2023-03-26_sendage.h5'
boulders = pd.read_hdf(filename, 'boulders')
ascents_df = pd.read_hdf(filename, 'ascents')
climbs_df = pd.read_hdf(filename, 'climbs')
climbers_df = pd.read_hdf(filename, 'climbers')

boulders = boulders.drop(136733)
boulders['# sends'] = boulders['# onsights'] + boulders['# redpoint'] + boulders['# flashes']
climbs_df['# sends'] = climbs_df['# onsights'] + climbs_df['# redpoint'] + climbs_df['# flashes']

# %%
boulders.loc[136733]
# Out:
# slug             disciple-prophet-wall-skaha-bc-canada
# name                                      The Disciple
# area_id                                          10385
# type                                           boulder
# grade_id                                            97
# bolts                                                0
# length                                             NaN
# grade                                                +
# description
# # onsights                                           0
# # redpoint                                           0
# # flashes                                            0
# # sends                                              0
# areas_0_name                                     Skaha
# areas_1_name                              Prophet Wall
# areas_2_name
# areas_0_slug                           skaha-bc-canada
# areas_1_slug              prophet-wall-skaha-bc-canada
# areas_2_slug
# areas_3_name
# areas_3_slug
# areas_4_name                                       NaN
# areas_4_slug                                       NaN
# areas_5_name                                       NaN
# areas_5_slug                                       NaN
# areas_6_name                                       NaN
# areas_6_slug                                       NaN
# areas_7_name                                       NaN
# areas_7_slug                                       NaN
# areas_8_name                                       NaN
# areas_8_slug                                       NaN
# areas_9_name                                       NaN
# areas_9_slug                                       NaN
# areas_10_name                                      NaN
# areas_11_name                                      NaN
# areas_10_slug                                      NaN
# areas_11_slug                                      NaN
# ratings_min                                        NaN
# ratings_max                                        NaN
# ratings_mean                                       NaN
# ratings_count                                      NaN
# stars_isna                                         NaN
# connected                                        False
# Name: 136733, dtype: object

# %%
def to_num_grade(s_grade):
    num_grade = pd.Series(np.zeros_like(s_grade), index=s_grade.index, name='V grade')
    filt = s_grade.str[-1]=='+'
    num_grade.loc[filt] = s_grade.loc[filt].str[1:-1].astype(int) + 0.25
    filt = s_grade.str[-1]=='-'
    num_grade.loc[filt] = s_grade.loc[filt].str[1:-1].astype(int) - 0.25
    filt = num_grade==0
    num_grade.loc[filt] = s_grade.loc[filt].str[1:].astype(int)
    return num_grade

# %%
boulders['V grade'] = to_num_grade(boulders['grade'])
boulders.head()
# Out:
#                                                     slug  \
# 36512  superfly-superfly-grand-wall-boulders-squamish...
# 36410  easy-in-easy-chair-easy-chair-grand-wall-bould...
# 36476  titanic-titanic-north-grand-wall-boulders-squa...
# 35610  trad-killer-heartbreak-hotel-grand-wall-boulde...
# 3049   timeless-titanic-south-grand-wall-boulders-squ...
#
#                         name  area_id     type  grade_id  bolts  length grade  \
# 36512               Superfly     8353  boulder        29      0     NaN    V4
# 36410  Easy In An Easy Chair     7521  boulder        29      0     NaN    V4
# 36476                Titanic     8360  boulder        24      0     NaN   V3+
# 35610            Trad Killer     8351  boulder        28      0     NaN    V4
# 3049                Timeless     8361  boulder        32      0     NaN   V5-
#
#                                              description  # onsights  \
# 36512  A Squamish all-time classic with physical move...          22
# 36410  Traverse left to right on good slopers. A clas...          27
# 36476  Start standing with opposing edges for your ha...          59
# 35610                                                             37
# 3049   Start matched on the big shelf and climb up an...          22
#
#        # redpoint  # flashes  # sends areas_0_name         areas_1_name  \
# 36512         575         74      671     Squamish  Grand Wall Boulders
# 36410         552         88      667     Squamish  Grand Wall Boulders
# 36476         465        133      657     Squamish  Grand Wall Boulders
# 35610         438         78      553     Squamish  Grand Wall Boulders
# 3049          414         84      520     Squamish  Grand Wall Boulders
#
#            areas_2_name        areas_0_slug  \
# 36512          Superfly  squamish-bc-canada
# 36410        Easy Chair  squamish-bc-canada
# 36476     Titanic North  squamish-bc-canada
# 35610  Heartbreak Hotel  squamish-bc-canada
# 3049      Titanic South  squamish-bc-canada
#
#                                  areas_1_slug  \
# 36512  grand-wall-boulders-squamish-bc-canada
# 36410  grand-wall-boulders-squamish-bc-canada
# 36476  grand-wall-boulders-squamish-bc-canada
# 35610  grand-wall-boulders-squamish-bc-canada
# 3049   grand-wall-boulders-squamish-bc-canada
#
#                                             areas_2_slug areas_3_name  \
# 36512    superfly-grand-wall-boulders-squamish-bc-canada
# 36410  easy-chair-grand-wall-boulders-squamish-bc-canada
# 36476  titanic-north-grand-wall-boulders-squamish-bc-...
# 35610  heartbreak-hotel-grand-wall-boulders-squamish-...
# 3049   titanic-south-grand-wall-boulders-squamish-bc-...
#
#       areas_3_slug areas_4_name areas_4_slug areas_5_name areas_5_slug  \
# 36512                       NaN          NaN          NaN          NaN
# 36410                       NaN          NaN          NaN          NaN
# 36476                       NaN          NaN          NaN          NaN
# 35610                       NaN          NaN          NaN          NaN
# 3049                        NaN          NaN          NaN          NaN
#
#       areas_6_name areas_6_slug areas_7_name areas_7_slug areas_8_name  \
# 36512          NaN          NaN          NaN          NaN          NaN
# 36410          NaN          NaN          NaN          NaN          NaN
# 36476          NaN          NaN          NaN          NaN          NaN
# 35610          NaN          NaN          NaN          NaN          NaN
# 3049           NaN          NaN          NaN          NaN          NaN
#
#       areas_8_slug areas_9_name areas_9_slug areas_10_name areas_11_name  \
# 36512          NaN          NaN          NaN           NaN           NaN
# 36410          NaN          NaN          NaN           NaN           NaN
# 36476          NaN          NaN          NaN           NaN           NaN
# 35610          NaN          NaN          NaN           NaN           NaN
# 3049           NaN          NaN          NaN           NaN           NaN
#
#       areas_10_slug areas_11_slug  ratings_min  ratings_max  ratings_mean  \
# 36512           NaN           NaN          2.0          5.0      4.143836
# 36410           NaN           NaN          1.0          5.0      4.071584
# 36476           NaN           NaN          1.0          5.0      3.929577
# 35610           NaN           NaN          1.0          5.0      4.149457
# 3049            NaN           NaN          2.0          5.0      4.168022
#
#        ratings_count  stars_isna  connected V grade
# 36512          438.0       233.0       True       4
# 36410          461.0       206.0       True       4
# 36476          426.0       231.0       True    3.25
# 35610          368.0       185.0       True       4
# 3049           369.0       151.0       True    4.75

# %%
boulders[boulders['name']=='A Quest for Pain']
# Out:
#                                                     slug              name  \
# 58635  quest-for-pain-ride-lightning-grand-wall-bould...  A Quest for Pain
#
#        area_id     type  grade_id  bolts  length grade description  \
# 58635     7249  boulder        18      0     NaN    V2
#
#        # onsights  # redpoint  # flashes  # sends areas_0_name  \
# 58635           1           6          1        8     Squamish
#
#               areas_1_name        areas_2_name        areas_0_slug  \
# 58635  Grand Wall Boulders  Ride the Lightning  squamish-bc-canada
#
#                                  areas_1_slug  \
# 58635  grand-wall-boulders-squamish-bc-canada
#
#                                             areas_2_slug areas_3_name  \
# 58635  ride-lightning-grand-wall-boulders-squamish-bc...
#
#       areas_3_slug areas_4_name areas_4_slug areas_5_name areas_5_slug  \
# 58635                       NaN          NaN          NaN          NaN
#
#       areas_6_name areas_6_slug areas_7_name areas_7_slug areas_8_name  \
# 58635          NaN          NaN          NaN          NaN          NaN
#
#       areas_8_slug areas_9_name areas_9_slug areas_10_name areas_11_name  \
# 58635          NaN          NaN          NaN           NaN           NaN
#
#       areas_10_slug areas_11_slug  ratings_min  ratings_max  ratings_mean  \
# 58635           NaN           NaN          3.0          5.0      3.833333
#
#        ratings_count  stars_isna  connected  V grade
# 58635            6.0         2.0       True      2.0

# %%
bascents = ascents_df[np.isin(ascents_df['climb_id'], boulders.index)]
bascents_dated = bascents[~bascents['date'].isna()]
climbers_, counts = np.unique(bascents_dated['user'], return_counts=True)
boulderers_dated = pd.DataFrame({'name': climbers_, '# sends': counts})

# %%
bascents_dated['V grade'] = to_num_grade(bascents_dated['grade'])
bascents_dated.head()
# Out:
# /var/folders/bj/_xdx3pvd5yx3t5gm46xh5b340000gn/T/ipykernel_3720/885950202.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bascents_dated['V grade'] = to_num_grade(bascents_dated['grade'])
#    climb_id                     user       date grade     style  first-ascent  \
# 0     36512                 hucklord 2023-02-12    V4  redpoint         False
# 1     36512                  rajsoni 2023-01-24    V4     flash         False
# 2     36512            maude-johnson 2022-11-01    V4  redpoint         False
# 3     36512      bethany-van-hierden 2022-10-20    V4  redpoint         False
# 4     36512  alessandroroome-sandrin 2022-10-12    V4  redpoint         False
#
#    stars comments beta V grade
# 0    5.0                     4
# 1    NaN                     4
# 2    5.0                     4
# 3    NaN  2nd go.            4
# 4    4.0                     4

# %% [markdown]
# ## squamish only

# %%
squamish_boulders = boulders[boulders['areas_0_name']=='Squamish']

squamish_boulders.loc[squamish_boulders['areas_1_name']=='The Powerline Boulders', 'areas_1_name'] = 'Powerline Boulders'
squamish_boulders.loc[squamish_boulders['areas_2_name']=='Parking Lot Wall', 'areas_2_name'] = 'Parking Lot'
climb_features = pd.concat([squamish_boulders[['V grade', 'ratings_mean']], 
                            # pd.get_dummies(squamish_boulders['areas_1_name']), 
                            # pd.get_dummies(squamish_boulders['areas_2_name'])
                           ], axis=1)
climb_features.head()
# Out:
#        V grade  ratings_mean
# 36512     4.00      4.143836
# 36410     4.00      4.071584
# 36476     3.25      3.929577
# 35610     4.00      4.149457
# 3049      4.75      4.168022

# %%
squamish_sends = bascents_dated[np.isin(bascents_dated['climb_id'], squamish_boulders.index)]

cat_type = CategoricalDtype(categories=["onsight", "flash", "redpoint"], ordered=True)
squamish_sends['style'] = squamish_sends['style'].astype(cat_type)
squamish_sends['style_num'] = squamish_sends['style'].cat.codes

squamish_sends.head()
# Out:
# /var/folders/bj/_xdx3pvd5yx3t5gm46xh5b340000gn/T/ipykernel_3720/1557487638.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squamish_sends['style'] = squamish_sends['style'].astype(cat_type)
# /var/folders/bj/_xdx3pvd5yx3t5gm46xh5b340000gn/T/ipykernel_3720/1557487638.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squamish_sends['style_num'] = squamish_sends['style'].cat.codes
#    climb_id                     user       date grade     style  first-ascent  \
# 0     36512                 hucklord 2023-02-12    V4  redpoint         False
# 1     36512                  rajsoni 2023-01-24    V4     flash         False
# 2     36512            maude-johnson 2022-11-01    V4  redpoint         False
# 3     36512      bethany-van-hierden 2022-10-20    V4  redpoint         False
# 4     36512  alessandroroome-sandrin 2022-10-12    V4  redpoint         False
#
#    stars comments beta  V grade  climb_token  style_num
# 0    5.0                    4.0            0          2
# 1    NaN                    4.0            0          1
# 2    5.0                    4.0            0          2
# 3    NaN  2nd go.           4.0            0          2
# 4    4.0                    4.0            0          2

# %%
n=5
tmp = squamish_sends.groupby('user')['climb_id'].count()
boulderers_min_n = tmp[tmp>n]
squamish_sends = squamish_sends[np.isin(squamish_sends['user'], boulderers_min_n.index)]
len(squamish_sends)
# Out:
# 54281

# %%
squamish_sends = squamish_sends.sort_values(['user', 'date'])#.set_index(['user', 'date'])
squamish_sends
# Out:
#         climb_id           user       date grade     style  first-ascent  \
# 772        36410    aaron-pardy 2021-02-27    V4  redpoint         False
# 112614    136621    aaron-pardy 2021-02-27   V0-   onsight         False
# 31707       3108    aaron-pardy 2021-04-04    V3  redpoint         False
# 63339      85045    aaron-pardy 2021-04-04    V2  redpoint         False
# 145908    136638    aaron-pardy 2021-04-04    V0  redpoint         False
# ...          ...            ...        ...   ...       ...           ...
# 110176    129022  zoebeauchemin 2022-10-02    V9  redpoint         False
# 12929      36485  zoebeauchemin 2023-03-21    V7  redpoint         False
# 117387     64154  zoebeauchemin 2023-03-21    V5  redpoint         False
# 50969      92069  zoebeauchemin 2023-03-22    V9  redpoint         False
# 66933       3076  zoebeauchemin 2023-03-22   V10  redpoint         False
#
#         stars                                           comments beta  \
# 772       5.0
# 112614    2.0
# 31707     3.0
# 63339     3.0
# 145908    3.0
# ...       ...                                                ...  ...
# 110176    4.0  Gnarly approach for the birks! Fun little prow...
# 12929     4.0
# 117387    3.0
# 50969     4.0
# 66933     3.0
#
#         V grade  climb_token  style_num
# 772        4.00            1          2
# 112614    -0.25         1431          0
# 31707      3.00          108          2
# 63339      2.00          334          2
# 145908     0.00         6320          2
# ...         ...          ...        ...
# 110176     9.00         1336          2
# 12929      7.00           35          2
# 117387     5.00         1690          2
# 50969      9.00          220          2
# 66933     10.00          367          2
#
# [54281 rows x 12 columns]

# %%
len(squamish_boulders)
# Out:
# 3328

# %%
squamish_boulders = squamish_boulders.loc[np.isin(squamish_boulders.index, squamish_sends['climb_id'])]
len(squamish_boulders)
# Out:
# 3000

# %%
counts = squamish_sends.groupby('climb_id')['user'].count().sort_values()
p_c = counts / counts.sum()
# np.histogram(np.log(p_c))
threshold = np.exp(-5.46578617)
p_dropped = 1 - np.sqrt(threshold/p_c)
p_dropped
# Out:
# climb_id
# 140683   -14.151078
# 124354   -14.151078
# 59452    -14.151078
# 124353   -14.151078
# 110652   -14.151078
#             ...
# 35610      0.234755
# 3049       0.238630
# 36476      0.271043
# 36410      0.281770
# 36512      0.283379
# Name: user, Length: 3000, dtype: float64

# %%
sequences = squamish_sends.groupby('user')['climb_id'].apply(list)
sequences
# Out:
# user
# aaron-pardy                  [36410, 136621, 3108, 85045, 136638, 57736, 75...
# aaronthebcsherpaiacovitti    [41980, 3117, 3068, 57237, 36512, 36410, 3095,...
# adam-curtis                  [3050, 3125, 36476, 3084, 3092, 42899, 36512, ...
# adam-fairweather             [10944, 3084, 3125, 42240, 3138, 41986, 58811,...
# adamandrewbanks              [41449, 3091, 3111, 3115, 36512, 36476, 35610,...
#                                                    ...
# zachary-whalen               [36476, 41980, 3102, 3045, 56417, 41937, 10944...
# zacharyjohnson               [107080, 10944, 3084, 42240, 55382, 41986, 418...
# zarinaguzman                 [85664, 85663, 102171, 102172, 93477, 102170, ...
# zibean                       [3049, 36444, 36476, 35982, 3058, 42872, 54461...
# zoebeauchemin                [36410, 36444, 42887, 36472, 3058, 36476, 3049...
# Name: climb_id, Length: 713, dtype: object

# %%
vocabulary = pd.Series(np.arange(len(squamish_boulders)), index=squamish_boulders.index)

# %%
inverse_vocabulary = pd.Series(squamish_boulders.index, index=np.arange(len(squamish_boulders)))

# %%
squamish_sends['climb_token'] = vocabulary.loc[squamish_sends['climb_id'].values].values

# %%
tokens = squamish_sends.groupby('user')['climb_token'].apply(list)
tokens
# Out:
# user
# aaron-pardy                  [1, 937, 108, 296, 2626, 150, 237, 322, 338, 3...
# aaroniacovitti                                  [82, 244, 20, 43, 59, 73, 254]
# aaronthebcsherpaiacovitti    [50, 118, 11, 51, 0, 1, 81, 254, 41, 59, 2958,...
# abby-taylor                                         [34, 49, 68, 77, 269, 270]
# adam-currie                               [19, 4, 8, 12, 36, 96, 112, 242, 51]
#                                                    ...
# zacharyjohnson               [1043, 14, 27, 65, 83, 87, 90, 183, 230, 240, ...
# zarinaguzman                 [781, 814, 178, 233, 243, 443, 700, 27, 49, 65...
# zehraozturk                           [118, 186, 6, 30, 3, 11, 4, 15, 26, 133]
# zibean                       [4, 6, 2, 20, 30, 33, 55, 19, 0, 1, 3, 7, 35, ...
# zoebeauchemin                [1, 6, 41, 5, 30, 2, 4, 33, 52, 39, 147, 412, ...
# Name: climb_token, Length: 862, dtype: object

# %%
i_ = np.arange(862)
np.random.shuffle(i_)
u_train, u_dev, u_test = np.split(i_, (650, 700))

# %% [markdown]
# # BC only

# %%
from process_area import combine_areas

# %%
bc_climbs, bc_ascents, bc_climbers, bc_boulders = combine_areas(['bc-canada'], path='/Users/larathompson/Downloads/')
# Out:
# Processing bc-canada
# Dropped bad dates: [7910, 62114]
# Combining ['bc-canada']
# 0.9946078431372549 0.8717074682367524
# 0.9946808510638298 0.906085237258348
# /Users/larathompson/code/cs224u/final project/sendage/process_area.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boulders['connected'] = np.isin(boulders.index, conn_bs)

# %%
bc_boulders = bc_boulders[~(bc_boulders['grade']=='+')]

# %%
# boulders = boulders.drop(136733)
bc_boulders['# sends'] = bc_boulders['# onsights'] + bc_boulders['# redpoint'] + bc_boulders['# flashes']
bc_climbs['# sends'] = bc_climbs['# onsights'] + bc_climbs['# redpoint'] + bc_climbs['# flashes']
# Out:
# /var/folders/bj/_xdx3pvd5yx3t5gm46xh5b340000gn/T/ipykernel_3720/2871457136.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bc_boulders['# sends'] = bc_boulders['# onsights'] + bc_boulders['# redpoint'] + bc_boulders['# flashes']

# %%
bc_boulders['V grade'] = to_num_grade(bc_boulders['grade'])
# Out:
# /var/folders/bj/_xdx3pvd5yx3t5gm46xh5b340000gn/T/ipykernel_3720/2457949017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bc_boulders['V grade'] = to_num_grade(bc_boulders['grade'])

# %%
cat_type = CategoricalDtype(categories=["onsight", "flash", "redpoint"], ordered=True)
bc_ascents['style'] = bc_ascents['style'].astype(cat_type)
bc_ascents['style_num'] = bc_ascents['style'].cat.codes

# %%
bc_boulders.head()
# Out:
#                                                     slug  \
# 36512  superfly-superfly-grand-wall-boulders-squamish...
# 36410  easy-in-easy-chair-easy-chair-grand-wall-bould...
# 36476  titanic-titanic-north-grand-wall-boulders-squa...
# 35610  trad-killer-heartbreak-hotel-grand-wall-boulde...
# 3049   timeless-titanic-south-grand-wall-boulders-squ...
#
#                         name  area_id     type  grade_id  bolts  length grade  \
# 36512               Superfly     8353  boulder        29      0     NaN    V4
# 36410  Easy In An Easy Chair     7521  boulder        29      0     NaN    V4
# 36476                Titanic     8360  boulder        24      0     NaN   V3+
# 35610            Trad Killer     8351  boulder        28      0     NaN    V4
# 3049                Timeless     8361  boulder        32      0     NaN   V5-
#
#                                              description  # onsights  \
# 36512  A Squamish all-time classic with physical move...          22
# 36410  Traverse left to right on good slopers. A clas...          27
# 36476  Start standing with opposing edges for your ha...          59
# 35610                                                             37
# 3049   Start matched on the big shelf and climb up an...          22
#
#        # redpoint  # flashes  # sends areas_0_name         areas_1_name  \
# 36512         575         74      671     Squamish  Grand Wall Boulders
# 36410         552         88      667     Squamish  Grand Wall Boulders
# 36476         465        133      657     Squamish  Grand Wall Boulders
# 35610         438         78      553     Squamish  Grand Wall Boulders
# 3049          414         84      520     Squamish  Grand Wall Boulders
#
#            areas_2_name        areas_0_slug  \
# 36512          Superfly  squamish-bc-canada
# 36410        Easy Chair  squamish-bc-canada
# 36476     Titanic North  squamish-bc-canada
# 35610  Heartbreak Hotel  squamish-bc-canada
# 3049      Titanic South  squamish-bc-canada
#
#                                  areas_1_slug  \
# 36512  grand-wall-boulders-squamish-bc-canada
# 36410  grand-wall-boulders-squamish-bc-canada
# 36476  grand-wall-boulders-squamish-bc-canada
# 35610  grand-wall-boulders-squamish-bc-canada
# 3049   grand-wall-boulders-squamish-bc-canada
#
#                                             areas_2_slug areas_3_name  \
# 36512    superfly-grand-wall-boulders-squamish-bc-canada
# 36410  easy-chair-grand-wall-boulders-squamish-bc-canada
# 36476  titanic-north-grand-wall-boulders-squamish-bc-...
# 35610  heartbreak-hotel-grand-wall-boulders-squamish-...
# 3049   titanic-south-grand-wall-boulders-squamish-bc-...
#
#       areas_3_slug areas_4_name areas_4_slug areas_5_name areas_5_slug  \
# 36512                       NaN          NaN          NaN          NaN
# 36410                       NaN          NaN          NaN          NaN
# 36476                       NaN          NaN          NaN          NaN
# 35610                       NaN          NaN          NaN          NaN
# 3049                        NaN          NaN          NaN          NaN
#
#       areas_6_name areas_6_slug areas_7_name areas_7_slug areas_8_name  \
# 36512          NaN          NaN          NaN          NaN          NaN
# 36410          NaN          NaN          NaN          NaN          NaN
# 36476          NaN          NaN          NaN          NaN          NaN
# 35610          NaN          NaN          NaN          NaN          NaN
# 3049           NaN          NaN          NaN          NaN          NaN
#
#       areas_8_slug areas_9_name areas_9_slug areas_10_name areas_11_name  \
# 36512          NaN          NaN          NaN           NaN           NaN
# 36410          NaN          NaN          NaN           NaN           NaN
# 36476          NaN          NaN          NaN           NaN           NaN
# 35610          NaN          NaN          NaN           NaN           NaN
# 3049           NaN          NaN          NaN           NaN           NaN
#
#       areas_10_slug areas_11_slug  ratings_min  ratings_max  ratings_mean  \
# 36512           NaN           NaN          2.0          5.0      4.143836
# 36410           NaN           NaN          1.0          5.0      4.071584
# 36476           NaN           NaN          1.0          5.0      3.929577
# 35610           NaN           NaN          1.0          5.0      4.149457
# 3049            NaN           NaN          2.0          5.0      4.168022
#
#        ratings_count  stars_isna  connected V grade
# 36512          438.0       233.0       True       4
# 36410          461.0       206.0       True       4
# 36476          426.0       231.0       True    3.25
# 35610          368.0       185.0       True       4
# 3049           369.0       151.0       True    4.75

# %%
def self_consistent_min(ascents, climbers, climbs, n_min=5):
    n_climbs, n_climbers = len(climbs)+1, len(climbers)+1
    while (len(climbs) < n_climbs) or (len(climbers) < n_climbers):
        n_climbs, n_climbers = len(climbs), len(climbers)
        print(n_climbs, n_climbers)
        
        # update ascents
        ascents = ascents[np.isin(ascents['user'], climbers.index)]
        ascents = ascents[np.isin(ascents['climb_id'], climbs.index)]
        
        # update climbers
        climbers_, counts = np.unique(ascents['user'], return_counts=True)
        climbers = climbers.loc[climbers_[counts >= n_min]]
        climbers['# sends'] = counts[counts >= n_min]
        
        # update climbs
        climb_styles = ascents.groupby(['climb_id', 'style'])['user'].count().reset_index().pivot(
            index='climb_id', columns='style', values='user').fillna(0)
        climb_styles['# sends'] = climb_styles.sum(axis=1)
        climb_styles = climb_styles[climb_styles['# sends']>=n_min]
        climbs = climbs.loc[climb_styles.index]
        climbs[climb_styles.columns] = climb_styles
        print(len(climbs), len(climbers))
    return ascents, climbers, climbs

# %%
bc_bascents = bc_ascents[np.isin(bc_ascents['climb_id'], bc_boulders.index) & ~bc_ascents['date'].isna()]

# %%
bc_bascents, bc_boulderers, bc_boulders_5 = self_consistent_min(bc_bascents, climbers_df.copy().set_index('name'), bc_boulders.copy())
# Out:
# 9103 2715
# 2858 1091
# 2858 1091
# 2849 1069
# 2849 1069
# 2844 1069
# 2844 1069
# 2844 1069

# %%
bc_bascents['V grade'] = to_num_grade(bc_bascents['grade'])
bc_bascents = bc_bascents.sort_values(['user', 'date', 'V grade'])

# %%
bc_bascents.head(50)
# Out:
#         climb_id         user       date grade     style  first-ascent  stars  \
# 88091     106461        aaron 2018-09-02    V0     flash         False    NaN
# 63521      93475        aaron 2018-09-02    V3  redpoint         False    4.0
# 10200       3082        aaron 2019-04-21    V3  redpoint         False    3.0
# 850        36410        aaron 2019-04-21    V4  redpoint         False    4.0
# 88654     116790        aaron 2019-05-02    V0     flash         False    2.0
# 82182     117675        aaron 2019-05-03    V0     flash         False    3.0
# 46006      80019        aaron 2019-05-03    V1  redpoint         False    3.0
# 58297      93408        aaron 2019-05-03    V1     flash         False    2.0
# 66102      93340        aaron 2019-05-03    V1     flash         False    2.0
# 50293      82756        aaron 2019-05-03    V2  redpoint         False    2.0
# 53312      93339        aaron 2019-05-03    V2  redpoint         False    NaN
# 76556      93338        aaron 2019-05-03    V2     flash         False    4.0
# 76586      93341        aaron 2019-05-03    V3  redpoint         False    3.0
# 31872      84081        aaron 2019-05-04    V4  redpoint         False    4.0
# 95997     117708        aaron 2019-05-05    V2  redpoint         False    4.0
# 82209     117709        aaron 2019-05-05    V4  redpoint         False    3.0
# 2614        3049        aaron 2021-07-11    V5  redpoint         False    5.0
# 112614    136621  aaron-pardy 2021-02-27   V0-   onsight         False    2.0
# 772        36410  aaron-pardy 2021-02-27    V4  redpoint         False    5.0
# 63339      85045  aaron-pardy 2021-04-04    V2  redpoint         False    3.0
# 31707       3108  aaron-pardy 2021-04-04    V3  redpoint         False    3.0
# 39774      57736  aaron-pardy 2021-04-11    V0   onsight         False    3.0
# 69214      42567  aaron-pardy 2021-04-11    V0   onsight         False    2.0
# 80921      42566  aaron-pardy 2021-04-11    V0  redpoint         False    2.0
# 81516      57737  aaron-pardy 2021-04-11    V0   onsight         False    2.0
# 55706      75555  aaron-pardy 2021-04-11    V1   onsight         False    2.0
# 73808      60763  aaron-pardy 2021-04-11    V1  redpoint         False    3.0
# 98296      93176  aaron-pardy 2021-04-11    V1   onsight         False    2.0
# 98316      93177  aaron-pardy 2021-04-11    V1   onsight         False    3.0
# 67229      75699  aaron-pardy 2021-04-11    V2  redpoint         False    3.0
# 89189      93174  aaron-pardy 2021-04-11    V3  redpoint         False    3.0
# 49994      42004  aaron-pardy 2021-04-16    V0   onsight         False    3.0
# 81082      83832  aaron-pardy 2021-04-16    V0  redpoint         False    2.0
# 118675    136622  aaron-pardy 2021-04-16    V0   onsight         False    3.0
# 25050       3095  aaron-pardy 2021-04-16    V2  redpoint         False    4.0
# 79         36512  aaron-pardy 2021-04-16    V4  redpoint         False    4.0
# 94810      41983  aaron-pardy 2021-04-17    V0   onsight         False    2.0
# 61864      41891  aaron-pardy 2021-04-17    V1   onsight         False    3.0
# 107305     93460  aaron-pardy 2021-04-17    V2  redpoint         False    3.0
# 92714      47872  aaron-pardy 2021-04-22    V0   onsight         False    3.0
# 64163      41914  aaron-pardy 2021-04-22    V1  redpoint         False    3.0
# 82284      47865  aaron-pardy 2021-04-22    V1   onsight         False    3.0
# 92873      84636  aaron-pardy 2021-04-22    V1   onsight         False    3.0
# 96026      41915  aaron-pardy 2021-04-22    V1   onsight         False    3.0
# 88591      41832  aaron-pardy 2021-04-22    V2  redpoint         False    3.0
# 92896      78640  aaron-pardy 2021-04-22   V3-  redpoint         False    2.0
# 46066      41870  aaron-pardy 2021-04-22    V3  redpoint         False    4.0
# 78995      42198  aaron-pardy 2021-04-22    V3  redpoint         False    3.0
# 55829      41978  aaron-pardy 2021-04-23    V0   onsight         False    2.0
# 90530      41925  aaron-pardy 2021-04-23    V1  redpoint         False    3.0
#
#                                 comments beta  style_num V grade
# 88091                      street shoes.               1       0
# 63521   good footwork and balance a must               2       3
# 10200                                                  2       3
# 850                                                    2       4
# 88654                                                  1       0
# 82182                                                  1       0
# 46006             big rock big climb yay               2       1
# 58297                                                  1       1
# 66102                                                  1       1
# 50293                                                  2       2
# 53312                                                  2       2
# 76556                                                  1       2
# 76586                                                  2       3
# 31872                                                  2       4
# 95997                                                  2       2
# 82209                                                  2       4
# 2614             Nice climb. Slopey top.               2       5
# 112614                                                 0   -0.25
# 772                                                    2       4
# 63339                                                  2       2
# 31707                                                  2       3
# 39774                                                  0       0
# 69214                                                  0       0
# 80921                                                  2       0
# 81516                                                  0       0
# 55706                                                  0       1
# 73808                                                  2       1
# 98296                                                  0       1
# 98316                                                  0       1
# 67229                                                  2       2
# 89189                                                  2       3
# 49994                                                  0       0
# 81082                                                  2       0
# 118675                                                 0       0
# 25050                                                  2       2
# 79                                                     2       4
# 94810                                                  0       0
# 61864                                                  0       1
# 107305                                                 2       2
# 92714                                                  0       0
# 64163                                                  2       1
# 82284                                                  0       1
# 92873                                                  0       1
# 96026                                                  0       1
# 88591                                                  2       2
# 92896                                                  2    2.75
# 46066                                                  2       3
# 78995                                                  2       3
# 55829                                                  0       0
# 90530                                                  2       1

# %%
counts = bc_bascents.groupby('climb_id')['user'].count().sort_values()
p_c = counts / counts.sum()
# np.histogram(np.log(p_c))
threshold = np.exp(-5.5)
p_dropped = 1 - np.sqrt(threshold/p_c)
p_dropped
# Out:
# climb_id
# 59141    -7.065102
# 72174    -7.065102
# 116310   -7.065102
# 42223    -7.065102
# 93527    -7.065102
#             ...
# 3049      0.201436
# 35610     0.221045
# 36476     0.280360
# 36410     0.284338
# 36512     0.289356
# Name: user, Length: 3013, dtype: float64

# %%
bc_boulders_5[bc_boulders_5['name']=='All Aboard the Swaize Express']
vocabulary.loc[93873]
# Out:
# 1477

# %%
vocabulary = pd.Series(np.arange(len(bc_boulders_5)), index=bc_boulders_5.index)
inverse_vocabulary = pd.Series(bc_boulders_5.index, index=np.arange(len(bc_boulders_5)))

bc_bascents['climb_token'] = vocabulary.loc[bc_bascents['climb_id'].values].values
bc_bascents.loc[bc_bascents['stars']==-1, 'stars'] = -5

features = {}
for feature in ['climb_token', 'V grade', 'style_num', 'stars', 'date']:
    features[feature] = bc_bascents.groupby('user')[feature].apply(list)
    holdout = features[feature].loc[['larathompson', 'finnfrasergrathwol']]
    features[feature] = pd.concat([features[feature].drop(['larathompson', 'finnfrasergrathwol']), holdout])
features
# Out:
# {'climb_token': user
#  aaron                        [1904, 1454, 18, 98, 2284, 2341, 921, 1450, 14...
#  aaron-pardy                  [2762, 98, 1112, 32, 591, 432, 431, 592, 833, ...
#  aaroniacovitti                               [128, 772, 1311, 132, 86, 95, 83]
#  aaronthebcsherpaiacovitti    [323, 37, 11, 579, 25, 106, 98, 1311, 466, 132...
#  abby-taylor                                        [328, 23, 42, 45, 298, 369]
#                                                     ...
#  zehraozturk                  [37, 135, 100, 9, 72, 1000, 1239, 2176, 2143, ...
#  zibean                       [5, 100, 103, 86, 9, 454, 560, 70, 106, 98, 72...
#  zoebeauchemin                [98, 100, 466, 102, 1516, 934, 9, 103, 5, 454,...
#  larathompson                 [1183, 1672, 1854, 1940, 1407, 581, 2294, 2312...
#  finnfrasergrathwol           [344, 1778, 1719, 72, 5, 1776, 1779, 442, 222,...
#  Name: climb_token, Length: 1069, dtype: object,
#  'V grade': user
#  aaron                        [0, 3, 3, 4, 0, 0, 1, 1, 1, 2, 2, 2, 3, 4, 2, ...
#  aaron-pardy                  [-0.25, 4, 2, 3, 0, 0, 0, 0, 1, 1, 1, 1, 2, 3,...
#  aaroniacovitti                                           [7, 8, 5, 6, 7, 7, 7]
#  aaronthebcsherpaiacovitti    [0, 4, 3, 4, 2, 4, 4, 5, 5, 6, 3, 4, 4, 4, 4, ...
#  abby-taylor                                             [-0.25, 1, 1, 1, 1, 1]
#                                                     ...
#  zehraozturk                  [4, 6.75, 5, 4, 4, 4, 3, 4, 4, 2.75, 2.25, 4, ...
#  zibean                        [5, 5, 3, 7, 4, 6, 6, 8, 4, 4, 4, 4, 7, 7, 5, 8]
#  zoebeauchemin                [4, 5, 6, 4, 4, 5, 4, 3, 4.75, 6.25, 6.75, 3.2...
#  larathompson                 [2, 2, 2, 2, 2, 3, 1.75, 2, 2, 2.75, 1.75, 2, ...
#  finnfrasergrathwol           [7, 0, 3.75, 4, 5, 5, 5, 7, 7, 7, 7, 3.75, 0, ...
#  Name: V grade, Length: 1069, dtype: object,
#  'style_num': user
#  aaron                        [1, 2, 2, 2, 1, 1, 2, 1, 1, 2, 2, 1, 2, 2, 2, ...
#  aaron-pardy                  [0, 2, 2, 2, 0, 0, 2, 0, 0, 2, 0, 0, 2, 2, 0, ...
#  aaroniacovitti                                           [2, 2, 2, 2, 2, 2, 2]
#  aaronthebcsherpaiacovitti    [1, 2, 2, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, ...
#  abby-taylor                                                 [1, 1, 1, 0, 1, 1]
#                                                     ...
#  zehraozturk                  [2, 2, 0, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 1, ...
#  zibean                        [2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, 1, 2, 1, 2]
#  zoebeauchemin                [2, 2, 2, 1, 1, 0, 1, 2, 2, 2, 2, 2, 2, 1, 0, ...
#  larathompson                 [2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 0, 2, 0, 2, 2, ...
#  finnfrasergrathwol           [2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, ...
#  Name: style_num, Length: 1069, dtype: object,
#  'stars': user
#  aaron                        [-5.0, 4.0, 3.0, 4.0, 2.0, 3.0, 3.0, 2.0, 2.0,...
#  aaron-pardy                  [2.0, 5.0, 3.0, 3.0, 3.0, 2.0, 2.0, 2.0, 2.0, ...
#  aaroniacovitti                            [3.0, 3.0, -5.0, 5.0, 5.0, 5.0, 4.0]
#  aaronthebcsherpaiacovitti    [-5.0, -5.0, -5.0, -5.0, -5.0, -5.0, -5.0, -5....
#  abby-taylor                                 [3.0, -5.0, -5.0, 3.0, -5.0, -5.0]
#                                                     ...
#  zehraozturk                  [-5.0, -5.0, -5.0, -5.0, -5.0, 3.0, -5.0, -5.0...
#  zibean                       [-5.0, -5.0, -5.0, -5.0, -5.0, -5.0, -5.0, -5....
#  zoebeauchemin                [5.0, 5.0, 4.0, 3.0, 3.0, 4.0, 4.0, 3.0, 4.0, ...
#  larathompson                 [5.0, 3.0, 5.0, 3.0, 2.0, 5.0, 2.0, 3.0, 4.0, ...
#  finnfrasergrathwol           [3.0, -5.0, -5.0, -5.0, -5.0, 4.0, 5.0, 3.0, -...
#  Name: stars, Length: 1069, dtype: object,
#  'date': user
#  aaron                        [2018-09-02 00:00:00, 2018-09-02 00:00:00, 201...
#  aaron-pardy                  [2021-02-27 00:00:00, 2021-02-27 00:00:00, 202...
#  aaroniacovitti               [2019-02-16 00:00:00, 2019-03-16 00:00:00, 201...
#  aaronthebcsherpaiacovitti    [2017-04-01 00:00:00, 2017-06-09 00:00:00, 201...
#  abby-taylor                  [2013-06-09 00:00:00, 2013-06-09 00:00:00, 201...
#                                                     ...
#  zehraozturk                  [2017-05-20 00:00:00, 2017-06-24 00:00:00, 201...
#  zibean                       [2021-08-11 00:00:00, 2021-08-14 00:00:00, 202...
#  zoebeauchemin                [2017-04-27 00:00:00, 2017-04-27 00:00:00, 201...
#  larathompson                 [2021-05-09 00:00:00, 2021-07-11 00:00:00, 202...
#  finnfrasergrathwol           [2016-08-04 00:00:00, 2016-08-14 00:00:00, 201...
#  Name: date, Length: 1069, dtype: object}

# %%
for i in range(1069): 
    features['date'].iloc[i] = [0]+list(np.diff(features['date'].iloc[i])/pd.Timedelta("1 days"))

# %%
i_ = np.arange(len(features['climb_token']))
np.random.shuffle(i_[:-2])
u_train, u_dev, u_test = np.split(i_, (int(0.85*len(tokens)), int(0.9*len(tokens))))
print(len(u_train), len(u_dev), len(u_test))
# Out:
# 908 54 107

# %% [markdown]
# ## all dated boulder sends

# %%
len(bascents_dated)
# Out:
# 144589

# %%
bascents_dated_dedupd = bascents_dated.sort_values(by='date').drop_duplicates(['user', 'climb_id'])

# %%
n=5
tmp = bascents_dated_dedupd.groupby('user')['climb_id'].count()
boulderers_min_n = tmp[tmp>n]
bascents_dated_min5 = bascents_dated_dedupd[np.isin(bascents_dated_dedupd['user'], boulderers_min_n.index)]
len(bascents_dated_min5)

# %%
bascents_dated_min10 = bascents_dated_min10.sort_values(['user', 'date', 'V grade'])

# %%
print(len(boulders))
boulders_dated = boulders.loc[np.isin(boulders.index, bascents_dated_min10['climb_id'])]
print(len(boulders_dated))
# Out:
# 26961
# 22063

# %%
vocabulary = pd.Series(np.arange(len(boulders_dated)), index=boulders_dated.index)
inverse_vocabulary = pd.Series(boulders_dated.index, index=np.arange(len(boulders_dated)))

# %%
bascents_dated_min10['climb_token'] = vocabulary.loc[bascents_dated_min10['climb_id'].values].values
tokens = bascents_dated_min10.groupby('user')['climb_token'].apply(list)
tokens
# Out:
# user
# aaron                        [701, 336, 14796, 14794, 14790, 14791, 14792, ...
# aaron-martinez               [10390, 10591, 10211, 10237, 10305, 10261, 106...
# aaron-pardy                  [1431, 1, 6310, 334, 108, 554, 390, 152, 570, ...
# aaronthebcsherpaiacovitti    [50, 120, 11, 51, 81, 0, 1, 282, 41, 59, 7706,...
# abby-huyler-2263             [10209, 10266, 10222, 15658, 15769, 15690, 156...
#                                                    ...
# zane-dordai                  [15663, 15658, 15723, 16266, 15674, 15777, 156...
# zarinaguzman                 [1187, 1115, 550, 4583, 265, 249, 184, 978, 40...
# zehraozturk                  [120, 193, 6, 30, 3, 520, 630, 263, 176, 11, 4...
# zibean                       [4, 6, 2, 20, 30, 33, 55, 19, 3, 1, 7, 0, 35, ...
# zoebeauchemin                [1, 6, 41, 160, 5, 114, 30, 2, 4, 33, 52, 445,...
# Name: climb_token, Length: 1229, dtype: object

# %%
i_tokens = np.arange(len(tokens))
np.random.shuffle(i_tokens)

u_train, u_dev, u_test = np.split(i_tokens, [1000, 1100])

# %%
len(u_train), len(u_dev), len(u_test)
# Out:
# (1000, 100, 129)

# %% [markdown]
# # make training data -- time slices

# %%
n = 10
i_t = 9

# %%
def all_user_seqs(features, udx, i_target=2, n=5):
    maxlen = features['climb_token'].str.len().max()
    idx = jnp.arange(maxlen - n + 1)[:, None] + jnp.arange(n)[None, :]
    mask = len(tokens)
    feat_mat = []
    for feature in features:
        mats = []
        for user, seq in features[feature].iloc[udx].items():
            l_seq = len(seq)
            if l_seq < n:
                mats.append(jnp.pad(jnp.array(seq), (n-l_seq, 0), 
                                    constant_values=mask if feature=='climb_token' else 0)[jnp.newaxis, :])
            else:
                mats.append(jnp.pad(jnp.array(seq), (0, maxlen-l_seq), constant_values=-1)[idx])
        mats = jnp.concatenate(mats, axis=0)
        mats = mats[~np.any(mats==-1, axis=1)]
        feat_mat.append(mats[:,:, jnp.newaxis])
    feat_mat = jnp.concatenate(feat_mat, axis=2)
    feat_mat = feat_mat.at[:, 0, -1].set(0)
    print(feat_mat.shape)
    x, y = jnp.concatenate([feat_mat[:, :i_target, :], feat_mat[:, i_target+1:, :]], axis=1), feat_mat[:, i_target, :].astype(jnp.int16)
    x = jnp.concatenate([x, jnp.concatenate([mask*jnp.ones(feat_mat.shape[0])[:, jnp.newaxis], y[:, 1:]], axis=1)[:, jnp.newaxis, :]], axis=1)
    y = y[:, 0]
    return x, y

# %%
dev_x[:, 0, 3]
# Out:
# Array([4.000e+00,       nan,       nan,       nan, 3.000e+00, 4.000e+00,
#        5.000e+00, 4.000e+00, 3.000e+00, 5.000e+00, 4.000e+00, 4.000e+00,
#        4.000e+00, 5.000e+00, 2.000e+00, 5.000e+00,       nan,       nan,
#              nan,       nan,       nan, 3.000e+00, 3.000e+00, 3.000e+00,
#        3.000e+00, 4.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 5.000e+00,
#        3.000e+00, 4.000e+00, 3.000e+00, 3.000e+00, 4.000e+00, 4.000e+00,
#        4.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 2.000e+00,
#        4.000e+00, 4.000e+00, 4.000e+00, 4.000e+00,       nan,       nan,
#        4.000e+00,       nan, 2.000e+00, 4.000e+00, 4.000e+00,       nan,
#        3.000e+00, 4.000e+00, 3.000e+00, 4.000e+00, 2.000e+00, 4.000e+00,
#        3.000e+00, 4.000e+00, 3.000e+00,       nan, 4.000e+00, 3.000e+00,
#              nan, 3.000e+00, 2.000e+00, 4.000e+00, 5.000e+00, 4.000e+00,
#        2.000e+00, 4.000e+00,       nan, 3.000e+00, 4.000e+00, 3.000e+00,
#              nan, 4.000e+00, 4.000e+00, 5.000e+00, 5.000e+00, 4.000e+00,
#        4.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 3.000e+00, 2.000e+00,
#        4.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 5.000e+00, 2.000e+00,
#              nan,       nan, 3.000e+00, 3.000e+00, 2.000e+00, 2.000e+00,
#        4.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 4.000e+00,
#        3.000e+00, 3.000e+00, 4.000e+00, 5.000e+00, 4.000e+00, 3.000e+00,
#        5.000e+00, 3.000e+00, 5.000e+00, 4.000e+00, 3.000e+00, 3.000e+00,
#        4.000e+00, 4.000e+00, 3.000e+00, 4.000e+00, 4.000e+00, 4.000e+00,
#        3.000e+00, 2.000e+00, 4.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        5.000e+00, 4.000e+00, 2.000e+00, 2.000e+00, 3.000e+00, 3.000e+00,
#        2.000e+00, 5.000e+00, 2.000e+00, 3.000e+00, 4.000e+00, 3.000e+00,
#        1.000e+00, 3.000e+00, 5.000e+00, 4.000e+00, 3.000e+00, 4.000e+00,
#        3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 4.000e+00, 3.000e+00,
#        3.000e+00, 3.000e+00, 2.000e+00, 3.000e+00, 2.000e+00, 3.000e+00,
#        3.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 3.000e+00,
#        4.000e+00, 3.000e+00, 2.000e+00, 3.000e+00, 4.000e+00, 3.000e+00,
#        4.000e+00, 4.000e+00, 5.000e+00, 2.000e+00, 3.000e+00, 3.000e+00,
#        3.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 3.000e+00, 3.000e+00,
#        3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 4.000e+00,
#        3.000e+00, 3.000e+00, 3.000e+00, 4.000e+00, 3.000e+00, 2.000e+00,
#        3.000e+00, 3.000e+00, 3.000e+00, 4.000e+00, 4.000e+00, 3.000e+00,
#        3.000e+00, 4.000e+00, 4.000e+00, 3.000e+00, 3.000e+00, 4.000e+00,
#        4.000e+00, 3.000e+00, 4.000e+00, 3.000e+00, 2.000e+00, 3.000e+00,
#        4.000e+00, 3.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 4.000e+00,
#        3.000e+00, 3.000e+00, 2.000e+00, 4.000e+00, 4.000e+00, 4.000e+00,
#        4.000e+00, 4.000e+00, 3.000e+00, 4.000e+00, 4.000e+00, 3.000e+00,
#        3.000e+00, 4.000e+00, 5.000e+00, 5.000e+00, 3.000e+00, 4.000e+00,
#        3.000e+00, 3.000e+00, 3.000e+00, 4.000e+00, 3.000e+00, 2.000e+00,
#        4.000e+00, 3.000e+00, 4.000e+00, 3.000e+00, 2.000e+00, 4.000e+00,
#        3.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 3.000e+00,
#        4.000e+00, 3.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 3.000e+00,
#        3.000e+00, 4.000e+00, 3.000e+00, 3.000e+00, 4.000e+00, 3.000e+00,
#        3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 3.000e+00,
#        5.000e+00, 2.000e+00, 4.000e+00, 4.000e+00, 3.000e+00, 4.000e+00,
#        5.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 3.000e+00, 3.000e+00,
#        4.000e+00, 4.000e+00, 2.000e+00, 3.000e+00, 5.000e+00, 3.000e+00,
#        3.000e+00, 4.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        4.000e+00, 5.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        3.000e+00, 4.000e+00, 2.000e+00, 2.000e+00, 3.000e+00, 4.000e+00,
#        3.000e+00, 3.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 1.000e+00,
#        4.000e+00, 4.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 3.000e+00,
#        4.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 3.000e+00,
#        3.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        3.000e+00, 4.000e+00, 2.000e+00, 2.000e+00, 4.000e+00, 4.000e+00,
#        3.000e+00, 3.000e+00, 4.000e+00, 4.000e+00, 3.000e+00, 3.000e+00,
#        3.000e+00, 3.000e+00, 4.000e+00, 3.000e+00, 4.000e+00, 3.000e+00,
#        3.000e+00, 4.000e+00, 4.000e+00, 3.000e+00, 2.000e+00, 3.000e+00,
#        2.000e+00, 3.000e+00, 2.000e+00, 2.000e+00, 3.000e+00, 2.000e+00,
#        3.000e+00, 2.000e+00, 3.000e+00, 4.000e+00, 4.000e+00, 4.000e+00,
#        3.000e+00, 4.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        2.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 2.000e+00, 3.000e+00,
#        4.000e+00, 4.000e+00, 4.000e+00, 3.000e+00, 4.000e+00, 3.000e+00,
#        3.000e+00, 2.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 4.000e+00,
#        3.000e+00, 3.000e+00, 3.000e+00, 4.000e+00, 4.000e+00, 3.000e+00,
#        3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 2.000e+00,
#        3.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 4.000e+00, 3.000e+00,
#        2.000e+00, 3.000e+00, 4.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        4.000e+00, 3.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 3.000e+00,
#        4.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 3.000e+00,
#        4.000e+00, 4.000e+00, 4.000e+00, 4.000e+00, 3.000e+00, 4.000e+00,
#        3.000e+00, 4.000e+00, 2.000e+00, 2.000e+00, 3.000e+00, 3.000e+00,
#        4.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 4.000e+00, 5.000e+00,
#        3.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 3.000e+00,
#        3.000e+00, 3.000e+00, 3.000e+00,       nan, 4.000e+00, 4.000e+00,
#        3.000e+00, 1.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        3.000e+00, 2.000e+00, 2.000e+00, 3.000e+00, 4.000e+00, 2.000e+00,
#        2.000e+00, 3.000e+00, 2.000e+00, 2.000e+00, 3.000e+00, 3.000e+00,
#        5.000e+00, 3.000e+00, 4.000e+00, 4.000e+00, 3.000e+00, 4.000e+00,
#        4.000e+00, 3.000e+00, 2.000e+00, 4.000e+00, 3.000e+00, 4.000e+00,
#        5.000e+00, 3.000e+00, 4.000e+00, 4.000e+00, 2.000e+00, 2.000e+00,
#        1.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 1.000e+00,
#        2.000e+00, 2.000e+00, 3.000e+00, 4.000e+00, 2.000e+00, 1.000e+00,
#        2.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 2.000e+00,
#        5.000e+00, 4.000e+00, 3.000e+00, 4.000e+00, 3.000e+00, 4.000e+00,
#        4.000e+00, 3.000e+00, 4.000e+00, 4.000e+00, 3.000e+00, 4.000e+00,
#        4.000e+00, 3.000e+00, 5.000e+00, 1.000e+00, 3.000e+00, 2.000e+00,
#        3.000e+00, 2.000e+00, 4.000e+00, 5.000e+00, 5.000e+00, 3.000e+00,
#        4.000e+00, 1.000e+00, 3.000e+00, 3.000e+00, 4.000e+00, 3.000e+00,
#        3.000e+00, 3.000e+00, 5.000e+00, 3.000e+00, 1.000e+00, 2.000e+00,
#        2.000e+00, 4.000e+00, 3.000e+00, 2.000e+00, 4.000e+00, 3.000e+00,
#        5.000e+00, 4.000e+00, 3.000e+00, 1.000e+00, 3.000e+00, 3.000e+00,
#        2.000e+00, 3.000e+00, 2.000e+00,       nan, 2.000e+00, 1.000e+00,
#        3.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        3.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 4.000e+00, 2.000e+00,
#        2.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 1.000e+00, 2.000e+00,
#        3.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 4.000e+00, 3.000e+00,
#        5.000e+00, 4.000e+00, 2.000e+00, 5.000e+00, 3.000e+00, 3.000e+00,
#        2.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        2.000e+00, 2.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 3.000e+00,
#        3.000e+00, 4.000e+00, 5.000e+00, 3.000e+00, 2.000e+00, 5.000e+00,
#        4.000e+00, 5.000e+00, 3.000e+00, 4.000e+00,       nan, 4.000e+00,
#        3.000e+00, 4.000e+00, 3.000e+00, 5.000e+00, 2.000e+00, 2.000e+00,
#        3.000e+00, 4.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 2.000e+00,
#        3.000e+00, 4.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        4.000e+00, 3.000e+00, 3.000e+00, 4.000e+00, 3.000e+00, 4.000e+00,
#        2.000e+00, 2.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
#        2.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 2.000e+00, 3.000e+00,
#        3.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 1.000e+00,
#        2.000e+00, 3.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 1.069e+03,
#              nan,       nan,       nan,       nan, 3.000e+00, 3.000e+00,
#        1.000e+00], dtype=float32)

# %%
train_x, train_y = all_user_seqs(features, u_train, i_target=i_t, n=n)
dev_x, dev_y = all_user_seqs(features, u_dev, i_target=i_t, n=n)
test_x, test_y = all_user_seqs(features, u_test, i_target=i_t, n=n)
# Out:
# (49165, 10, 5)
# (4130, 10, 5)
# (6153, 10, 5)

# %%
me_x, me_y = all_user_seqs(features, [1067], i_target=i_t, n=n)
finn_x, finn_y = all_user_seqs(features, [1068], i_target=i_t, n=n)
# Out:
# (77, 10, 5)
# (106, 10, 5)

# %%
train_x.shape, train_y.shape, dev_x.shape, dev_y.shape, test_x.shape, test_y.shape
# Out:
# ((49165, 10, 5), (49165,), (4130, 10, 5), (4130,), (6153, 10, 5), (6153,))

# %% [markdown]
# # make training data -- time ordered samples

# %%
n = 10

# %%
def random_user_seqs(tokens, i_target=2, n=5):
    rng = np.random.default_rng()
    mats = []
    for user, seq in tokens.items():
        for _ in range(4*(len(seq)-n)):
            idx = np.sort(rng.choice(len(seq), n, replace=False))
            mats.append(jnp.array(seq)[idx])
    mats = jnp.row_stack(mats)
    return jnp.concatenate([mats[:, :i_target], mats[:, i_target+1:]], axis=1), mats[:, i_target]

# %%
train_x, train_y = random_user_seqs(tokens.iloc[u_train], i_target=n-1, n=n)
dev_x, dev_y = random_user_seqs(tokens.iloc[u_dev], i_target=n-1, n=n)
test_x, test_y = random_user_seqs(tokens.iloc[u_test], i_target=n-1, n=n)

# %%
train_x.shape
# Out:
# (416648, 9)

# %% [markdown]
# # Sequence Modelling

# %% [markdown]
# ## Model definitions

# %%
class Climb2Vec(nn.Module):
    vocab : int
    d : int
    
    @nn.compact
    def __call__(self, X_batch, training):
        x = nn.Embed(self.vocab, self.d)(X_batch)
        # x = nn.Dropout(0.2, deterministic=not training)(x)
        x = x.reshape(X_batch.shape[0], -1)
        x = nn.relu(nn.Dense(128)(x))
        x = nn.Dropout(0.2, deterministic=not training)(x)
        x = nn.Dense(self.vocab)(x)
        return x

# %%
class ClimbGRU(nn.Module):
    vocab : int
    d : int
    features: int
    
    @nn.compact
    def __call__(self, x, training):
        batch_size = x.shape[0]
        x = jnp.concatenate([nn.Embed(self.vocab, self.d)(x[:, :, 0].astype(jnp.int16)),
                             x[:, :, 1:]], axis=2)
        
        ScanGRUCell = nn.scan(
            nn.GRUCell, variable_broadcast="params",
            split_rngs={"params": False}, in_axes=1, out_axes=1)
        carry = nn.GRUCell.initialize_carry(
            jax.random.PRNGKey(0), (batch_size,), self.features)
        carry, x = ScanGRUCell()(carry, x)
        
        ScanGRUCell = nn.scan(
            nn.GRUCell, variable_broadcast="params",
            split_rngs={"params": False}, in_axes=1, out_axes=1)
        carry = nn.GRUCell.initialize_carry(
            jax.random.PRNGKey(0), (batch_size,), self.features)
        carry, x = ScanGRUCell()(carry, x)
        
        x = nn.Dense(self.vocab)(carry)

        return x

# %%
class ClimbLSTM(nn.Module):
    vocab : int
    d : int
    features: int
    
    @nn.compact
    def __call__(self, x, training):
        batch_size = x.shape[0]
        x = nn.Embed(self.vocab, self.d)(x)
        x = nn.Dropout(0.1, deterministic=not training)(x)
        
        ScanLSTMCell = nn.scan(
            nn.LSTMCell, variable_broadcast="params",
            split_rngs={"params": False}, in_axes=1, out_axes=1)
        carry = nn.LSTMCell.initialize_carry(
            jax.random.PRNGKey(0), (batch_size,), self.features)
        carry, x = ScanLSTMCell()(carry, x)
        # ScanLSTMCell = nn.scan(
        #     nn.LSTMCell, variable_broadcast="params",
        #     split_rngs={"params": False}, in_axes=1, out_axes=1)
        # carry = nn.LSTMCell.initialize_carry(
        #     jax.random.PRNGKey(0), (batch_size,), self.features)
        # carry, x = ScanLSTMCell()(carry, x)
        
        x = x.reshape(batch_size, -1)
        # x = nn.relu(nn.Dense(128)(x))
        x = nn.Dense(self.vocab)(x)
        return x

# %%
batch_size = 256
batch_idx = np.arange(batch_size*(len(train_x) // batch_size))
np.random.shuffle(batch_idx)
batch_idx = np.reshape(batch_idx, (-1, batch_size))

rng = jax.random.PRNGKey(42)

rng, inp_rng, init_rng, dropout_rng = jax.random.split(rng, 4)
inp = jax.random.randint(inp_rng, (batch_size, n-1, 5), 0, 1)

vocab = len(vocabulary)+1
d_emb = 100
d_rnn = 128

# model = Climb2Vec(vocab, d_emb)
# initial_params = model.init(init_rng, inp, training=False)

model = ClimbGRU(vocab, d_emb, d_rnn)
initial_params = model.init(init_rng, inp, training=False)

# %%
def loss(params: optax.Params, batch: jnp.ndarray, labels: jnp.ndarray) -> jnp.ndarray:
    y_hat = model.apply(params, batch, training=True, rngs={'dropout': dropout_rng})
    loss_value = optax.softmax_cross_entropy_with_integer_labels(y_hat, labels)
    
    return loss_value.mean()

# %%
params = initial_params

e_loss = []
e_acc = []
e_sm = []

i_epoch = 0

@jax.jit
def step(params, opt_state, batch, labels):
    loss_value, grads = jax.value_and_grad(loss)(params, batch, labels)
    updates, opt_state = optimizer.update(grads, opt_state, params)
    params = optax.apply_updates(params, updates)
    return params, opt_state, loss_value

schedule = optax.warmup_cosine_decay_schedule(
    init_value=1e-5,
    peak_value=1e-3,
    warmup_steps=20,
    decay_steps=1000,
    end_value=1e-4
)

optimizer = optax.adam(learning_rate=1e-3)

opt_state = optimizer.init(params)

best_params = params
best_sm = 10
best_acc = 0
wait = 5

# %%
num_epochs = 5

for epoch in range(num_epochs):
    losses = []
    for i, idx in enumerate(batch_idx):
        batch, labels = train_x[idx], train_y[idx]
        params, opt_state, loss_value = step(params, opt_state, batch, labels)
        losses.append(loss_value)
    e_loss.append(np.mean(losses))
    dev_p = model.apply(params, dev_x, training=False)
    e_acc.append(np.mean(dev_p.argmax(axis=-1) == dev_y))
    e_sm.append(np.mean(optax.softmax_cross_entropy_with_integer_labels(dev_p, dev_y)))
    print(f'epoch {i_epoch + epoch}\t loss: {e_loss[-1]:.4f}; val_sm: {e_sm[-1]:.4f}; val_acc: {e_acc[-1]:.4f}')
    
    if e_acc[-1] > best_acc:  #e_sm[-1] < best_sm:
        best_acc = e_acc[-1]
        best_params = params
    if (epoch > wait) and np.all(e_sm[-1] > np.array(e_sm[-wait-1:-1])):
        break
        
i_epoch += num_epochs
# Out:
# epoch 5	 loss: 4.5277; val_sm: 5.0028; val_acc: 0.0925
# epoch 6	 loss: 4.2863; val_sm: 4.8488; val_acc: 0.1133
# epoch 7	 loss: 4.0758; val_sm: 4.7180; val_acc: 0.1278
# epoch 8	 loss: 3.8890; val_sm: 4.5915; val_acc: 0.1402
# epoch 9	 loss: 3.7207; val_sm: 4.5032; val_acc: 0.1538

# %%
test_p = model.apply(best_params, test_x, training=False)
np.mean(test_p.argmax(axis=-1) == test_y), np.mean(optax.softmax_cross_entropy_with_integer_labels(test_p, test_y))
# Out:
# (Array(0.18348773, dtype=float32), Array(4.412322, dtype=float32))

# %%
me_p = model.apply(best_params, me_x, training=False).argmax(axis=-1)
finn_p = model.apply(best_params, finn_x, training=False).argmax(axis=-1)

# %%
np.mean(me_p==me_y), np.mean(finn_p==finn_y)
# Out:
# (Array(0.14285715, dtype=float32), Array(0.1509434, dtype=float32))

# %%
def print_results(true, predicted, seqs, mistakes=True):
    if mistakes:
        show = true != predicted
    else:
        show = true == predicted
    actual = bc_boulders_5.loc[inverse_vocabulary.loc[true[show]].values, ['name', 'grade']].values
    otherwise = bc_boulders_5.loc[inverse_vocabulary.loc[predicted[show]].values, ['name', 'grade']].values
    context = [bc_boulders_5.loc[inverse_vocabulary.loc[row].values, 'name'].tolist() for row in np.array(seqs[show])]
    rows = []
    for i in range(len(actual)):
        rows.append(context[i] + list(actual[i]) + list(otherwise[i]))
    return pd.DataFrame(rows)

# %%
print_results(me_y, me_p, me_x[:, :, 0], mistakes=True)
# Out:
#                                        0   \
# 0                               The Peeve
# 1                        Freeman's Warmup
# 2                      Snakes and Ladders
# 3                            Bass Fishing
# 4                      Green Eggs and Sam
# 5                     Stairway to Nowhere
# 6                          Buddha's Belly
# 7                             Middle Monk
# 8                            Punk Ass Kid
# 9                    Ladybug Strikes Back
# 10                   New Kid on the Block
# 11                       Old Man Mountain
# 12                     Calabogie Dreaming
# 13                         Mantel la Mesa
# 14                            Big Bottoms
# 15                            Tennis Star
# 16                                The Wiz
# 17                           Shade Mantel
# 18                              Shineater
# 19                                  Jenga
# 20                       Masaki's Problem
# 21          All Aboard the Swaize Express
# 22                              Backtrack
# 23                                Titanic
# 24                              Split Pea
# 25                             Eight Ball
# 26                  A Well Healed Peabody
# 27                           The Hangover
# 28                                Erotica
# 29                           Goin' Postal
# 30                                 Aurora
# 31                     Hollyburn Traverse
# 32                               Erratica
# 33                     ChickenHead Mantel
# 34                              Slingshot
# 35                         Anatomy Lesson
# 36                            Bo Jo Jones
# 37                             Left Brain
# 38                         Crack Slabbath
# 39                            Broken Nose
# 40                            Second Wind
# 41                        Second Wind Low
# 42                               Escargot
# 43                             Leprechaun
# 44                        Godman Gunsmoke
# 45                              Feel Good
# 46                           Lazy Ladybug
# 47                             Scoop Dogg
# 48                                Dervish
# 49                      My Latest Mistake
# 50                     Double Edged Sword
# 51                            Pumpkin Pie
# 52                              Apple Pie
# 53                    Dark Prince Righter
# 54                    Cave Dweller Center
# 55                            The Floater
# 56                            ChossABlock
# 57                                Poached
# 58                            Centre Slab
# 59                      Portable - Mantle
# 60                                Treeson
# 61                    Last, but not Elise
# 62  Bert and Ernie Were Just Good Friends
# 63                      Surfin' on Heroin
# 64                        Black Bear Slab
# 65                          Cheese Grater
#
#                                        1   \
# 0                        Freeman's Warmup
# 1                          Fisheye Biceps
# 2                            Bass Fishing
# 3                      Green Eggs and Sam
# 4                     Stairway to Nowhere
# 5                          Buddha's Belly
# 6                             Middle Monk
# 7                            Punk Ass Kid
# 8                    Ladybug Strikes Back
# 9                    New Kid on the Block
# 10                       Old Man Mountain
# 11                       Dark Prince Left
# 12                         Mantel la Mesa
# 13                            Big Bottoms
# 14                            Tennis Star
# 15                                The Wiz
# 16                           Shade Mantel
# 17                              Shineater
# 18                               Tiny Tim
# 19                      Eager Puppy Short
# 20          All Aboard the Swaize Express
# 21                              Backtrack
# 22                               The Pawn
# 23                              Split Pea
# 24                             Eight Ball
# 25                  A Well Healed Peabody
# 26                             Beef Broth
# 27                                Erotica
# 28                           Goin' Postal
# 29                                 Aurora
# 30                     Hollyburn Traverse
# 31                               Erratica
# 32                        Remembrance Day
# 33                              Slingshot
# 34                         Anatomy Lesson
# 35                            Bo Jo Jones
# 36                             Left Brain
# 37                         Crack Slabbath
# 38                            Broken Nose
# 39                            Second Wind
# 40                        Second Wind Low
# 41                               Escargot
# 42                             Leprechaun
# 43                        Godman Gunsmoke
# 44                              Feel Good
# 45                           Lazy Ladybug
# 46                             Scoop Dogg
# 47                                Dervish
# 48                      My Latest Mistake
# 49                     Double Edged Sword
# 50                            Pumpkin Pie
# 51                              Apple Pie
# 52                    Dark Prince Righter
# 53                    Cave Dweller Center
# 54                            The Floater
# 55                            ChossABlock
# 56                                Poached
# 57                            Centre Slab
# 58                      Portable - Mantle
# 59                                Treeson
# 60                    Last, but not Elise
# 61  Bert and Ernie Were Just Good Friends
# 62                      Surfin' on Heroin
# 63                        Black Bear Slab
# 64                          Cheese Grater
# 65                     Up From The Depths
#
#                                        2   \
# 0                          Fisheye Biceps
# 1                      Snakes and Ladders
# 2                      Green Eggs and Sam
# 3                     Stairway to Nowhere
# 4                          Buddha's Belly
# 5                             Middle Monk
# 6                            Punk Ass Kid
# 7                    Ladybug Strikes Back
# 8                    New Kid on the Block
# 9                        Old Man Mountain
# 10                       Dark Prince Left
# 11                     Calabogie Dreaming
# 12                            Big Bottoms
# 13                            Tennis Star
# 14                                The Wiz
# 15                           Shade Mantel
# 16                              Shineater
# 17                               Tiny Tim
# 18                                  Jenga
# 19                       Masaki's Problem
# 20                              Backtrack
# 21                               The Pawn
# 22                             Tumbleweed
# 23                             Eight Ball
# 24                  A Well Healed Peabody
# 25                             Beef Broth
# 26                           The Hangover
# 27                           Goin' Postal
# 28                                 Aurora
# 29                     Hollyburn Traverse
# 30                               Erratica
# 31                        Remembrance Day
# 32                     ChickenHead Mantel
# 33                         Anatomy Lesson
# 34                            Bo Jo Jones
# 35                             Left Brain
# 36                         Crack Slabbath
# 37                            Broken Nose
# 38                            Second Wind
# 39                        Second Wind Low
# 40                               Escargot
# 41                             Leprechaun
# 42                        Godman Gunsmoke
# 43                              Feel Good
# 44                           Lazy Ladybug
# 45                             Scoop Dogg
# 46                                Dervish
# 47                      My Latest Mistake
# 48                     Double Edged Sword
# 49                            Pumpkin Pie
# 50                              Apple Pie
# 51                    Dark Prince Righter
# 52                    Cave Dweller Center
# 53                            The Floater
# 54                            ChossABlock
# 55                                Poached
# 56                            Centre Slab
# 57                      Portable - Mantle
# 58                                Treeson
# 59                    Last, but not Elise
# 60  Bert and Ernie Were Just Good Friends
# 61                      Surfin' on Heroin
# 62                        Black Bear Slab
# 63                          Cheese Grater
# 64                     Up From The Depths
# 65                                 Slabby
#
#                                        3   \
# 0                      Snakes and Ladders
# 1                            Bass Fishing
# 2                     Stairway to Nowhere
# 3                          Buddha's Belly
# 4                             Middle Monk
# 5                            Punk Ass Kid
# 6                    Ladybug Strikes Back
# 7                    New Kid on the Block
# 8                        Old Man Mountain
# 9                        Dark Prince Left
# 10                     Calabogie Dreaming
# 11                         Mantel la Mesa
# 12                            Tennis Star
# 13                                The Wiz
# 14                           Shade Mantel
# 15                              Shineater
# 16                               Tiny Tim
# 17                                  Jenga
# 18                      Eager Puppy Short
# 19          All Aboard the Swaize Express
# 20                               The Pawn
# 21                             Tumbleweed
# 22                        Largonian Bulge
# 23                  A Well Healed Peabody
# 24                             Beef Broth
# 25                           The Hangover
# 26                                Erotica
# 27                                 Aurora
# 28                     Hollyburn Traverse
# 29                               Erratica
# 30                        Remembrance Day
# 31                     ChickenHead Mantel
# 32                              Slingshot
# 33                            Bo Jo Jones
# 34                             Left Brain
# 35                         Crack Slabbath
# 36                            Broken Nose
# 37                            Second Wind
# 38                        Second Wind Low
# 39                               Escargot
# 40                             Leprechaun
# 41                        Godman Gunsmoke
# 42                              Feel Good
# 43                           Lazy Ladybug
# 44                             Scoop Dogg
# 45                                Dervish
# 46                      My Latest Mistake
# 47                     Double Edged Sword
# 48                            Pumpkin Pie
# 49                              Apple Pie
# 50                    Dark Prince Righter
# 51                    Cave Dweller Center
# 52                            The Floater
# 53                            ChossABlock
# 54                                Poached
# 55                            Centre Slab
# 56                      Portable - Mantle
# 57                                Treeson
# 58                    Last, but not Elise
# 59  Bert and Ernie Were Just Good Friends
# 60                      Surfin' on Heroin
# 61                        Black Bear Slab
# 62                          Cheese Grater
# 63                     Up From The Depths
# 64                                 Slabby
# 65                           Ghost Buster
#
#                                        4   \
# 0                            Bass Fishing
# 1                      Green Eggs and Sam
# 2                          Buddha's Belly
# 3                             Middle Monk
# 4                            Punk Ass Kid
# 5                    Ladybug Strikes Back
# 6                    New Kid on the Block
# 7                        Old Man Mountain
# 8                        Dark Prince Left
# 9                      Calabogie Dreaming
# 10                         Mantel la Mesa
# 11                            Big Bottoms
# 12                                The Wiz
# 13                           Shade Mantel
# 14                              Shineater
# 15                               Tiny Tim
# 16                                  Jenga
# 17                      Eager Puppy Short
# 18                       Masaki's Problem
# 19                              Backtrack
# 20                             Tumbleweed
# 21                        Largonian Bulge
# 22                                Titanic
# 23                             Beef Broth
# 24                           The Hangover
# 25                                Erotica
# 26                           Goin' Postal
# 27                     Hollyburn Traverse
# 28                               Erratica
# 29                        Remembrance Day
# 30                     ChickenHead Mantel
# 31                              Slingshot
# 32                         Anatomy Lesson
# 33                             Left Brain
# 34                         Crack Slabbath
# 35                            Broken Nose
# 36                            Second Wind
# 37                        Second Wind Low
# 38                               Escargot
# 39                             Leprechaun
# 40                        Godman Gunsmoke
# 41                              Feel Good
# 42                           Lazy Ladybug
# 43                             Scoop Dogg
# 44                                Dervish
# 45                      My Latest Mistake
# 46                     Double Edged Sword
# 47                            Pumpkin Pie
# 48                              Apple Pie
# 49                    Dark Prince Righter
# 50                    Cave Dweller Center
# 51                            The Floater
# 52                            ChossABlock
# 53                                Poached
# 54                            Centre Slab
# 55                      Portable - Mantle
# 56                                Treeson
# 57                    Last, but not Elise
# 58  Bert and Ernie Were Just Good Friends
# 59                      Surfin' on Heroin
# 60                        Black Bear Slab
# 61                          Cheese Grater
# 62                     Up From The Depths
# 63                                 Slabby
# 64                           Ghost Buster
# 65                                 Shazam
#
#                                        5   \
# 0                      Green Eggs and Sam
# 1                     Stairway to Nowhere
# 2                             Middle Monk
# 3                            Punk Ass Kid
# 4                    Ladybug Strikes Back
# 5                    New Kid on the Block
# 6                        Old Man Mountain
# 7                        Dark Prince Left
# 8                      Calabogie Dreaming
# 9                          Mantel la Mesa
# 10                            Big Bottoms
# 11                            Tennis Star
# 12                           Shade Mantel
# 13                              Shineater
# 14                               Tiny Tim
# 15                                  Jenga
# 16                      Eager Puppy Short
# 17                       Masaki's Problem
# 18          All Aboard the Swaize Express
# 19                               The Pawn
# 20                        Largonian Bulge
# 21                                Titanic
# 22                              Split Pea
# 23                           The Hangover
# 24                                Erotica
# 25                           Goin' Postal
# 26                                 Aurora
# 27                               Erratica
# 28                        Remembrance Day
# 29                     ChickenHead Mantel
# 30                              Slingshot
# 31                         Anatomy Lesson
# 32                            Bo Jo Jones
# 33                         Crack Slabbath
# 34                            Broken Nose
# 35                            Second Wind
# 36                        Second Wind Low
# 37                               Escargot
# 38                             Leprechaun
# 39                        Godman Gunsmoke
# 40                              Feel Good
# 41                           Lazy Ladybug
# 42                             Scoop Dogg
# 43                                Dervish
# 44                      My Latest Mistake
# 45                     Double Edged Sword
# 46                            Pumpkin Pie
# 47                              Apple Pie
# 48                    Dark Prince Righter
# 49                    Cave Dweller Center
# 50                            The Floater
# 51                            ChossABlock
# 52                                Poached
# 53                            Centre Slab
# 54                      Portable - Mantle
# 55                                Treeson
# 56                    Last, but not Elise
# 57  Bert and Ernie Were Just Good Friends
# 58                      Surfin' on Heroin
# 59                        Black Bear Slab
# 60                          Cheese Grater
# 61                     Up From The Depths
# 62                                 Slabby
# 63                           Ghost Buster
# 64                                 Shazam
# 65                        Everyday Helmet
#
#                                        6   \
# 0                     Stairway to Nowhere
# 1                          Buddha's Belly
# 2                            Punk Ass Kid
# 3                    Ladybug Strikes Back
# 4                    New Kid on the Block
# 5                        Old Man Mountain
# 6                        Dark Prince Left
# 7                      Calabogie Dreaming
# 8                          Mantel la Mesa
# 9                             Big Bottoms
# 10                            Tennis Star
# 11                                The Wiz
# 12                              Shineater
# 13                               Tiny Tim
# 14                                  Jenga
# 15                      Eager Puppy Short
# 16                       Masaki's Problem
# 17          All Aboard the Swaize Express
# 18                              Backtrack
# 19                             Tumbleweed
# 20                                Titanic
# 21                              Split Pea
# 22                             Eight Ball
# 23                                Erotica
# 24                           Goin' Postal
# 25                                 Aurora
# 26                     Hollyburn Traverse
# 27                        Remembrance Day
# 28                     ChickenHead Mantel
# 29                              Slingshot
# 30                         Anatomy Lesson
# 31                            Bo Jo Jones
# 32                             Left Brain
# 33                            Broken Nose
# 34                            Second Wind
# 35                        Second Wind Low
# 36                               Escargot
# 37                             Leprechaun
# 38                        Godman Gunsmoke
# 39                              Feel Good
# 40                           Lazy Ladybug
# 41                             Scoop Dogg
# 42                                Dervish
# 43                      My Latest Mistake
# 44                     Double Edged Sword
# 45                            Pumpkin Pie
# 46                              Apple Pie
# 47                    Dark Prince Righter
# 48                    Cave Dweller Center
# 49                            The Floater
# 50                            ChossABlock
# 51                                Poached
# 52                            Centre Slab
# 53                      Portable - Mantle
# 54                                Treeson
# 55                    Last, but not Elise
# 56  Bert and Ernie Were Just Good Friends
# 57                      Surfin' on Heroin
# 58                        Black Bear Slab
# 59                          Cheese Grater
# 60                     Up From The Depths
# 61                                 Slabby
# 62                           Ghost Buster
# 63                                 Shazam
# 64                        Everyday Helmet
# 65                            Trad Killer
#
#                                        7   \
# 0                          Buddha's Belly
# 1                             Middle Monk
# 2                    Ladybug Strikes Back
# 3                    New Kid on the Block
# 4                        Old Man Mountain
# 5                        Dark Prince Left
# 6                      Calabogie Dreaming
# 7                          Mantel la Mesa
# 8                             Big Bottoms
# 9                             Tennis Star
# 10                                The Wiz
# 11                           Shade Mantel
# 12                               Tiny Tim
# 13                                  Jenga
# 14                      Eager Puppy Short
# 15                       Masaki's Problem
# 16          All Aboard the Swaize Express
# 17                              Backtrack
# 18                               The Pawn
# 19                        Largonian Bulge
# 20                              Split Pea
# 21                             Eight Ball
# 22                  A Well Healed Peabody
# 23                           Goin' Postal
# 24                                 Aurora
# 25                     Hollyburn Traverse
# 26                               Erratica
# 27                     ChickenHead Mantel
# 28                              Slingshot
# 29                         Anatomy Lesson
# 30                            Bo Jo Jones
# 31                             Left Brain
# 32                         Crack Slabbath
# 33                            Second Wind
# 34                        Second Wind Low
# 35                               Escargot
# 36                             Leprechaun
# 37                        Godman Gunsmoke
# 38                              Feel Good
# 39                           Lazy Ladybug
# 40                             Scoop Dogg
# 41                                Dervish
# 42                      My Latest Mistake
# 43                     Double Edged Sword
# 44                            Pumpkin Pie
# 45                              Apple Pie
# 46                    Dark Prince Righter
# 47                    Cave Dweller Center
# 48                            The Floater
# 49                            ChossABlock
# 50                                Poached
# 51                            Centre Slab
# 52                      Portable - Mantle
# 53                                Treeson
# 54                    Last, but not Elise
# 55  Bert and Ernie Were Just Good Friends
# 56                      Surfin' on Heroin
# 57                        Black Bear Slab
# 58                          Cheese Grater
# 59                     Up From The Depths
# 60                                 Slabby
# 61                           Ghost Buster
# 62                                 Shazam
# 63                        Everyday Helmet
# 64                            Trad Killer
# 65                    Under the Staircase
#
#                                        8           9   \
# 0                             Middle Monk  Green Slab
# 1                            Punk Ass Kid  Green Slab
# 2                    New Kid on the Block  Green Slab
# 3                        Old Man Mountain  Green Slab
# 4                        Dark Prince Left  Green Slab
# 5                      Calabogie Dreaming  Green Slab
# 6                          Mantel la Mesa  Green Slab
# 7                             Big Bottoms  Green Slab
# 8                             Tennis Star  Green Slab
# 9                                 The Wiz  Green Slab
# 10                           Shade Mantel  Green Slab
# 11                              Shineater  Green Slab
# 12                                  Jenga  Green Slab
# 13                      Eager Puppy Short  Green Slab
# 14                       Masaki's Problem  Green Slab
# 15          All Aboard the Swaize Express  Green Slab
# 16                              Backtrack  Green Slab
# 17                               The Pawn  Green Slab
# 18                             Tumbleweed  Green Slab
# 19                                Titanic  Green Slab
# 20                             Eight Ball  Green Slab
# 21                  A Well Healed Peabody  Green Slab
# 22                             Beef Broth  Green Slab
# 23                                 Aurora  Green Slab
# 24                     Hollyburn Traverse  Green Slab
# 25                               Erratica  Green Slab
# 26                        Remembrance Day  Green Slab
# 27                              Slingshot  Green Slab
# 28                         Anatomy Lesson  Green Slab
# 29                            Bo Jo Jones  Green Slab
# 30                             Left Brain  Green Slab
# 31                         Crack Slabbath  Green Slab
# 32                            Broken Nose  Green Slab
# 33                        Second Wind Low  Green Slab
# 34                               Escargot  Green Slab
# 35                             Leprechaun  Green Slab
# 36                        Godman Gunsmoke  Green Slab
# 37                              Feel Good  Green Slab
# 38                           Lazy Ladybug  Green Slab
# 39                             Scoop Dogg  Green Slab
# 40                                Dervish  Green Slab
# 41                      My Latest Mistake  Green Slab
# 42                     Double Edged Sword  Green Slab
# 43                            Pumpkin Pie  Green Slab
# 44                              Apple Pie  Green Slab
# 45                    Dark Prince Righter  Green Slab
# 46                    Cave Dweller Center  Green Slab
# 47                            The Floater  Green Slab
# 48                            ChossABlock  Green Slab
# 49                                Poached  Green Slab
# 50                            Centre Slab  Green Slab
# 51                      Portable - Mantle  Green Slab
# 52                                Treeson  Green Slab
# 53                    Last, but not Elise  Green Slab
# 54  Bert and Ernie Were Just Good Friends  Green Slab
# 55                      Surfin' on Heroin  Green Slab
# 56                        Black Bear Slab  Green Slab
# 57                          Cheese Grater  Green Slab
# 58                     Up From The Depths  Green Slab
# 59                                 Slabby  Green Slab
# 60                           Ghost Buster  Green Slab
# 61                                 Shazam  Green Slab
# 62                        Everyday Helmet  Green Slab
# 63                            Trad Killer  Green Slab
# 64                    Under the Staircase  Green Slab
# 65                               Option B  Green Slab
#
#                                        10   11                      12   13
# 0                            Punk Ass Kid   V3     Divergent Variation  V3-
# 1                    Ladybug Strikes Back   V2               S on My D   V1
# 2                        Old Man Mountain   V2               S on My D   V1
# 3                        Dark Prince Left   V3            Cowboy Bebop   V2
# 4                      Calabogie Dreaming   V3     Dark Prince Righter   V3
# 5                          Mantel la Mesa  V2-               S on My D   V1
# 6                             Big Bottoms   V2              Tumbleweed   V2
# 7                             Tennis Star  V1+                Option B  V2-
# 8                                 The Wiz  V2-                Hydrogen   V2
# 9                            Shade Mantel  V3+              Death Star   V3
# 10                              Shineater   V3               Slingshot  V2-
# 11                               Tiny Tim  V3-                   Jenga   V4
# 12                      Eager Puppy Short   V2               Slingshot  V2-
# 13                       Masaki's Problem   V2                 Titanic  V3+
# 14          All Aboard the Swaize Express  V5-                   Jenga   V4
# 15                              Backtrack   V2               Moby Dick   V1
# 16                               The Pawn   V2                   Bravo   V1
# 17                             Tumbleweed   V2              Sandtwitch  V2-
# 18                        Largonian Bulge  V2-             Big Bottoms   V2
# 19                              Split Pea   V1               One Track   V1
# 20                  A Well Healed Peabody   V3  Eight Ball Side Pocket   V3
# 21                             Beef Broth  V2-        Corn Flake Crack  V0+
# 22                           The Hangover   V2              Moon Moves   V1
# 23                     Hollyburn Traverse   V3                Erratica  V3-
# 24                               Erratica  V3-           Hang ‘em High   V3
# 25                        Remembrance Day  V3-      Hollyburn Traverse   V3
# 26                     ChickenHead Mantel   V2        Little Red Poppy   V1
# 27                         Anatomy Lesson  V3-         American Gigolo   V3
# 28                            Bo Jo Jones  V3-            Shade Mantel  V3+
# 29                             Left Brain  V2-                Paperboy   V2
# 30                         Crack Slabbath   V2                Paperboy   V2
# 31                            Broken Nose   V2        Lipsmack SitDown   V2
# 32                            Second Wind   V2                Paperboy   V2
# 33                               Escargot   V2        Little Red Poppy   V1
# 34                             Leprechaun   V1        Little Red Poppy   V1
# 35                        Godman Gunsmoke   V2        Little Red Poppy   V1
# 36                              Feel Good   V3      Hollyburn Traverse   V3
# 37                           Lazy Ladybug   V3      Green Eggs and Sam   V3
# 38                             Scoop Dogg   V3     Cave Dweller Center  V4-
# 39                                Dervish   V3     Cave Dweller Center  V4-
# 40                      My Latest Mistake   V3     Cave Dweller Center  V4-
# 41                     Double Edged Sword   V3    Ladybug Strikes Back   V2
# 42                            Pumpkin Pie   V4     Cave Dweller Center  V4-
# 43                              Apple Pie  V4-      Nothing Like Viper   V4
# 44                    Dark Prince Righter   V3             Onedercling   V1
# 45                    Cave Dweller Center  V4-             Dark Prince   V5
# 46                            The Floater   V4      Nothing Like Viper   V4
# 47                            ChossABlock  V2-            Lola Ladybug   V1
# 48                                Poached   V2                Option B  V2-
# 49                            Centre Slab   V3         Old And Serious   V3
# 50                      Portable - Mantle   V4          Anatomy Lesson  V3-
# 51                                Treeson   V2              Left Brain  V2-
# 52                    Last, but not Elise   V2                  Slabby   V2
# 53  Bert and Ernie Were Just Good Friends  V3+              Sandtwitch  V2-
# 54                      Surfin' on Heroin   V2             White Bread  V1+
# 55                        Black Bear Slab   V2             Bo Jo Crimp   V1
# 56                          Cheese Grater   V1               Slingshot  V2-
# 57                     Up From The Depths   V2               Slingshot  V2-
# 58                                 Slabby   V2          Crack Slabbath   V2
# 59                           Ghost Buster   V3             Centre Slab   V3
# 60                                 Shazam   V4          Speech Therapy   V3
# 61                        Everyday Helmet   V5           Depths Direct  V4+
# 62                            Trad Killer   V4             Shots Fired   V4
# 63                    Under the Staircase   V1             White Bread  V1+
# 64                               Option B  V2-        Heartbreak Hotel   V2
# 65                           Nadia's Slab   V1           Cheese Grater   V1

# %%
print_results(finn_y, finn_p, finn_x[:, :, 0], mistakes=True)
# Out:
#                                0                              1   \
# 0                University Crawl                   Moss Highway
# 1                    Moss Highway                      Macho man
# 2                       Macho man                    Trad Killer
# 3                     Trad Killer                       Timeless
# 4                        Timeless                        Vertigo
# 5                       The force         Breakfast at Tiffany's
# 6          Breakfast at Tiffany's                     Quickstick
# 7                      Quickstick                          Oscar
# 8                           Oscar                Peninsula Pinch
# 9                 Peninsula Pinch                    Equilibrium
# 10                    Equilibrium                      Dumb Slab
# 11                      Dumb Slab              Made In The Shade
# 12              Made In The Shade                   Shade Mantel
# 13                   Shade Mantel                    Bo Jo Jones
# 14                   Harry's Rail         The Killing Floor Left
# 15         The Killing Floor Left                     The Sickle
# 16                     The Sickle                        Big Boy
# 17                        Big Boy                     Real World
# 18                     Real World                  Swank Stretch
# 19                     Lounge Act                       Latch On
# 20                       Latch On           Can't Do It In Shoes
# 21           Can't Do It In Shoes                   Gastonomical
# 22                   Gastonomical                   Sloppy Poppy
# 23                   Sloppy Poppy                         Galaxy
# 24                         Galaxy                 Detached Flake
# 25                 Detached Flake                     Flow Stone
# 26                     Flow Stone                   Space Monkey
# 27                   Space Monkey                 Ride the Waves
# 28                 Ride the Waves      The Land That Time Forgot
# 29      The Land That Time Forgot                  Cradle Robber
# 30                  Cradle Robber           A Tribe Called Quest
# 31           A Tribe Called Quest         Creekside Mega Problem
# 32         Creekside Mega Problem                 Speech Therapy
# 33                 Speech Therapy                The Golden Bowl
# 34                The Golden Bowl             Swami of the Creek
# 35             Swami of the Creek             Flake Traverse Low
# 36             Flake Traverse Low                     Mindbender
# 37                    Centre Slab                           Boat
# 38                           Boat                     Palminator
# 39                     Palminator         Super Daddy Long Limbs
# 40         Super Daddy Long Limbs                    Words of Me
# 41                    Words of Me             Spotters on Strike
# 42             Spotters on Strike                           Hewy
# 43                           Hewy                           Lewy
# 44                           Lewy                           Dewy
# 45                           Dewy                American Gigolo
# 46                American Gigolo                 Tea Bag Undies
# 47                 Tea Bag Undies                    Middle cave
# 48                    Middle cave                        Acetone
# 49                      Superdyke                 Squealing Pork
# 50                      Sali Bong                 Lie Back Crack
# 51                 Lie Back Crack                  Finger of God
# 52                  Finger of God                    Tic Tac Toe
# 53                    Tic Tac Toe             Snakes and Ladders
# 54             Snakes and Ladders                          Jenga
# 55                          Jenga                          Alien
# 56                          Alien                    Faceburster
# 57                    Faceburster  All Aboard the Swaize Express
# 58  All Aboard the Swaize Express                      Rib Rider
# 59                      Rib Rider               Back Door Bandit
# 60               Back Door Bandit                      Surf's Up
# 61                      Surf's Up                     Surf Arete
# 62                   In Your Face              French Connection
# 63              French Connection                      The Crimp
# 64                      The Crimp                  Littlest Hobo
# 65                  Littlest Hobo                         Peeler
# 66                         Peeler                    Hummingbird
# 67                    Hummingbird                  Killa Gorilla
# 68                  Killa Gorilla                    Tai Fighter
# 69                  Little Dragon                      Prow Left
# 70             Practical Horseman                          Re-up
# 71                          Re-up                       Left Rib
# 72                       Left Rib                          Drone
# 73                          Drone          Sloppy Poppy Traverse
# 74          Sloppy Poppy Traverse                     Black Mark
# 75                     Black Mark                Airtight Garage
# 76                    Shots Fired                   The Silencer
# 77               Loki Shoots Fire                       Superfly
# 78                       Superfly                 Superfly Lunge
# 79                 Superfly Lunge                      Hip Check
# 80                      Hip Check                     Golden Boy
# 81                     Golden Boy                            911
# 82                            911                          The I
# 83                     The Tugger                   What a Beaut
# 84                   What a Beaut              How Neat is That?
# 85              How Neat is That?               What a Beaut Low
# 86               What a Beaut Low                       Aquarium
# 87                       Aquarium                  Lanky Horvath
# 88                  Lanky Horvath                      Fish Tank
# 89                      Fish Tank               Propane, Propane
#
#                                2                              3   \
# 0                       Macho man                    Trad Killer
# 1                     Trad Killer                       Timeless
# 2                        Timeless                        Vertigo
# 3                         Vertigo                      The force
# 4                       The force         Breakfast at Tiffany's
# 5                      Quickstick                          Oscar
# 6                           Oscar                Peninsula Pinch
# 7                 Peninsula Pinch                    Equilibrium
# 8                     Equilibrium                      Dumb Slab
# 9                       Dumb Slab              Made In The Shade
# 10              Made In The Shade                   Shade Mantel
# 11                   Shade Mantel                    Bo Jo Jones
# 12                    Bo Jo Jones                   Harry's Rail
# 13                   Harry's Rail         The Killing Floor Left
# 14                     The Sickle                        Big Boy
# 15                        Big Boy                     Real World
# 16                     Real World                  Swank Stretch
# 17                  Swank Stretch                     Lounge Act
# 18                     Lounge Act                       Latch On
# 19           Can't Do It In Shoes                   Gastonomical
# 20                   Gastonomical                   Sloppy Poppy
# 21                   Sloppy Poppy                         Galaxy
# 22                         Galaxy                 Detached Flake
# 23                 Detached Flake                     Flow Stone
# 24                     Flow Stone                   Space Monkey
# 25                   Space Monkey                 Ride the Waves
# 26                 Ride the Waves      The Land That Time Forgot
# 27      The Land That Time Forgot                  Cradle Robber
# 28                  Cradle Robber           A Tribe Called Quest
# 29           A Tribe Called Quest         Creekside Mega Problem
# 30         Creekside Mega Problem                 Speech Therapy
# 31                 Speech Therapy                The Golden Bowl
# 32                The Golden Bowl             Swami of the Creek
# 33             Swami of the Creek             Flake Traverse Low
# 34             Flake Traverse Low                     Mindbender
# 35                     Mindbender                    Centre Slab
# 36                    Centre Slab                           Boat
# 37                     Palminator         Super Daddy Long Limbs
# 38         Super Daddy Long Limbs                    Words of Me
# 39                    Words of Me             Spotters on Strike
# 40             Spotters on Strike                           Hewy
# 41                           Hewy                           Lewy
# 42                           Lewy                           Dewy
# 43                           Dewy                American Gigolo
# 44                American Gigolo                 Tea Bag Undies
# 45                 Tea Bag Undies                    Middle cave
# 46                    Middle cave                        Acetone
# 47                        Acetone               The Boss's Crack
# 48               The Boss's Crack                     Prow Right
# 49                      Sali Bong                 Lie Back Crack
# 50                  Finger of God                    Tic Tac Toe
# 51                    Tic Tac Toe             Snakes and Ladders
# 52             Snakes and Ladders                          Jenga
# 53                          Jenga                          Alien
# 54                          Alien                    Faceburster
# 55                    Faceburster  All Aboard the Swaize Express
# 56  All Aboard the Swaize Express                      Rib Rider
# 57                      Rib Rider               Back Door Bandit
# 58               Back Door Bandit                      Surf's Up
# 59                      Surf's Up                     Surf Arete
# 60                     Surf Arete                   In Your Face
# 61                   In Your Face              French Connection
# 62                      The Crimp                  Littlest Hobo
# 63                  Littlest Hobo                         Peeler
# 64                         Peeler                    Hummingbird
# 65                    Hummingbird                  Killa Gorilla
# 66                  Killa Gorilla                    Tai Fighter
# 67                    Tai Fighter                  Little Dragon
# 68                  Little Dragon                      Prow Left
# 69             Practical Horseman                          Re-up
# 70                       Left Rib                          Drone
# 71                          Drone          Sloppy Poppy Traverse
# 72          Sloppy Poppy Traverse                     Black Mark
# 73                     Black Mark                Airtight Garage
# 74                Airtight Garage                    Shots Fired
# 75                    Shots Fired                   The Silencer
# 76               Loki Shoots Fire                       Superfly
# 77                 Superfly Lunge                      Hip Check
# 78                      Hip Check                     Golden Boy
# 79                     Golden Boy                            911
# 80                            911                          The I
# 81                          The I     Backwards in an Easy Chair
# 82     Backwards in an Easy Chair                     The Tugger
# 83              How Neat is That?               What a Beaut Low
# 84               What a Beaut Low                       Aquarium
# 85                       Aquarium                  Lanky Horvath
# 86                  Lanky Horvath                      Fish Tank
# 87                      Fish Tank               Propane, Propane
# 88               Propane, Propane                     Shark Tank
# 89                     Shark Tank                      Albatross
#
#                                4                              5   \
# 0                        Timeless                        Vertigo
# 1                         Vertigo                      The force
# 2                       The force         Breakfast at Tiffany's
# 3          Breakfast at Tiffany's                     Quickstick
# 4                      Quickstick                          Oscar
# 5                 Peninsula Pinch                    Equilibrium
# 6                     Equilibrium                      Dumb Slab
# 7                       Dumb Slab              Made In The Shade
# 8               Made In The Shade                   Shade Mantel
# 9                    Shade Mantel                    Bo Jo Jones
# 10                    Bo Jo Jones                   Harry's Rail
# 11                   Harry's Rail         The Killing Floor Left
# 12         The Killing Floor Left                     The Sickle
# 13                     The Sickle                        Big Boy
# 14                     Real World                  Swank Stretch
# 15                  Swank Stretch                     Lounge Act
# 16                     Lounge Act                       Latch On
# 17                       Latch On           Can't Do It In Shoes
# 18           Can't Do It In Shoes                   Gastonomical
# 19                   Sloppy Poppy                         Galaxy
# 20                         Galaxy                 Detached Flake
# 21                 Detached Flake                     Flow Stone
# 22                     Flow Stone                   Space Monkey
# 23                   Space Monkey                 Ride the Waves
# 24                 Ride the Waves      The Land That Time Forgot
# 25      The Land That Time Forgot                  Cradle Robber
# 26                  Cradle Robber           A Tribe Called Quest
# 27           A Tribe Called Quest         Creekside Mega Problem
# 28         Creekside Mega Problem                 Speech Therapy
# 29                 Speech Therapy                The Golden Bowl
# 30                The Golden Bowl             Swami of the Creek
# 31             Swami of the Creek             Flake Traverse Low
# 32             Flake Traverse Low                     Mindbender
# 33                     Mindbender                    Centre Slab
# 34                    Centre Slab                           Boat
# 35                           Boat                     Palminator
# 36                     Palminator         Super Daddy Long Limbs
# 37                    Words of Me             Spotters on Strike
# 38             Spotters on Strike                           Hewy
# 39                           Hewy                           Lewy
# 40                           Lewy                           Dewy
# 41                           Dewy                American Gigolo
# 42                American Gigolo                 Tea Bag Undies
# 43                 Tea Bag Undies                    Middle cave
# 44                    Middle cave                        Acetone
# 45                        Acetone               The Boss's Crack
# 46               The Boss's Crack                     Prow Right
# 47                     Prow Right          Easy In An Easy Chair
# 48          Easy In An Easy Chair                      Superdyke
# 49                  Finger of God                    Tic Tac Toe
# 50             Snakes and Ladders                          Jenga
# 51                          Jenga                          Alien
# 52                          Alien                    Faceburster
# 53                    Faceburster  All Aboard the Swaize Express
# 54  All Aboard the Swaize Express                      Rib Rider
# 55                      Rib Rider               Back Door Bandit
# 56               Back Door Bandit                      Surf's Up
# 57                      Surf's Up                     Surf Arete
# 58                     Surf Arete                   In Your Face
# 59                   In Your Face              French Connection
# 60              French Connection                      The Crimp
# 61                      The Crimp                  Littlest Hobo
# 62                         Peeler                    Hummingbird
# 63                    Hummingbird                  Killa Gorilla
# 64                  Killa Gorilla                    Tai Fighter
# 65                    Tai Fighter                  Little Dragon
# 66                  Little Dragon                      Prow Left
# 67                      Prow Left             Practical Horseman
# 68             Practical Horseman                          Re-up
# 69                       Left Rib                          Drone
# 70          Sloppy Poppy Traverse                     Black Mark
# 71                     Black Mark                Airtight Garage
# 72                Airtight Garage                    Shots Fired
# 73                    Shots Fired                   The Silencer
# 74                   The Silencer               Loki Shoots Fire
# 75               Loki Shoots Fire                       Superfly
# 76                 Superfly Lunge                      Hip Check
# 77                     Golden Boy                            911
# 78                            911                          The I
# 79                          The I     Backwards in an Easy Chair
# 80     Backwards in an Easy Chair                     The Tugger
# 81                     The Tugger                   What a Beaut
# 82                   What a Beaut              How Neat is That?
# 83                       Aquarium                  Lanky Horvath
# 84                  Lanky Horvath                      Fish Tank
# 85                      Fish Tank               Propane, Propane
# 86               Propane, Propane                     Shark Tank
# 87                     Shark Tank                      Albatross
# 88                      Albatross           Tim's Sloper Problem
# 89           Tim's Sloper Problem                       Dr. Evil
#
#                                6                              7   \
# 0                       The force         Breakfast at Tiffany's
# 1          Breakfast at Tiffany's                     Quickstick
# 2                      Quickstick                          Oscar
# 3                           Oscar                Peninsula Pinch
# 4                 Peninsula Pinch                    Equilibrium
# 5                       Dumb Slab              Made In The Shade
# 6               Made In The Shade                   Shade Mantel
# 7                    Shade Mantel                    Bo Jo Jones
# 8                     Bo Jo Jones                   Harry's Rail
# 9                    Harry's Rail         The Killing Floor Left
# 10         The Killing Floor Left                     The Sickle
# 11                     The Sickle                        Big Boy
# 12                        Big Boy                     Real World
# 13                     Real World                  Swank Stretch
# 14                     Lounge Act                       Latch On
# 15                       Latch On           Can't Do It In Shoes
# 16           Can't Do It In Shoes                   Gastonomical
# 17                   Gastonomical                   Sloppy Poppy
# 18                   Sloppy Poppy                         Galaxy
# 19                 Detached Flake                     Flow Stone
# 20                     Flow Stone                   Space Monkey
# 21                   Space Monkey                 Ride the Waves
# 22                 Ride the Waves      The Land That Time Forgot
# 23      The Land That Time Forgot                  Cradle Robber
# 24                  Cradle Robber           A Tribe Called Quest
# 25           A Tribe Called Quest         Creekside Mega Problem
# 26         Creekside Mega Problem                 Speech Therapy
# 27                 Speech Therapy                The Golden Bowl
# 28                The Golden Bowl             Swami of the Creek
# 29             Swami of the Creek             Flake Traverse Low
# 30             Flake Traverse Low                     Mindbender
# 31                     Mindbender                    Centre Slab
# 32                    Centre Slab                           Boat
# 33                           Boat                     Palminator
# 34                     Palminator         Super Daddy Long Limbs
# 35         Super Daddy Long Limbs                    Words of Me
# 36                    Words of Me             Spotters on Strike
# 37                           Hewy                           Lewy
# 38                           Lewy                           Dewy
# 39                           Dewy                American Gigolo
# 40                American Gigolo                 Tea Bag Undies
# 41                 Tea Bag Undies                    Middle cave
# 42                    Middle cave                        Acetone
# 43                        Acetone               The Boss's Crack
# 44               The Boss's Crack                     Prow Right
# 45                     Prow Right          Easy In An Easy Chair
# 46          Easy In An Easy Chair                      Superdyke
# 47                      Superdyke                 Squealing Pork
# 48                 Squealing Pork                      Sali Bong
# 49             Snakes and Ladders                          Jenga
# 50                          Alien                    Faceburster
# 51                    Faceburster  All Aboard the Swaize Express
# 52  All Aboard the Swaize Express                      Rib Rider
# 53                      Rib Rider               Back Door Bandit
# 54               Back Door Bandit                      Surf's Up
# 55                      Surf's Up                     Surf Arete
# 56                     Surf Arete                   In Your Face
# 57                   In Your Face              French Connection
# 58              French Connection                      The Crimp
# 59                      The Crimp                  Littlest Hobo
# 60                  Littlest Hobo                         Peeler
# 61                         Peeler                    Hummingbird
# 62                  Killa Gorilla                    Tai Fighter
# 63                    Tai Fighter                  Little Dragon
# 64                  Little Dragon                      Prow Left
# 65                      Prow Left             Practical Horseman
# 66             Practical Horseman                          Re-up
# 67                          Re-up                       Left Rib
# 68                       Left Rib                          Drone
# 69          Sloppy Poppy Traverse                     Black Mark
# 70                Airtight Garage                    Shots Fired
# 71                    Shots Fired                   The Silencer
# 72                   The Silencer               Loki Shoots Fire
# 73               Loki Shoots Fire                       Superfly
# 74                       Superfly                 Superfly Lunge
# 75                 Superfly Lunge                      Hip Check
# 76                     Golden Boy                            911
# 77                          The I     Backwards in an Easy Chair
# 78     Backwards in an Easy Chair                     The Tugger
# 79                     The Tugger                   What a Beaut
# 80                   What a Beaut              How Neat is That?
# 81              How Neat is That?               What a Beaut Low
# 82               What a Beaut Low                       Aquarium
# 83                      Fish Tank               Propane, Propane
# 84               Propane, Propane                     Shark Tank
# 85                     Shark Tank                      Albatross
# 86                      Albatross           Tim's Sloper Problem
# 87           Tim's Sloper Problem                       Dr. Evil
# 88                       Dr. Evil                 Mantel Madness
# 89                 Mantel Madness                      El Camino
#
#                                8           9                           10  \
# 0                      Quickstick  Green Slab                       Oscar
# 1                           Oscar  Green Slab             Peninsula Pinch
# 2                 Peninsula Pinch  Green Slab                 Equilibrium
# 3                     Equilibrium  Green Slab                   Dumb Slab
# 4                       Dumb Slab  Green Slab           Made In The Shade
# 5                    Shade Mantel  Green Slab                 Bo Jo Jones
# 6                     Bo Jo Jones  Green Slab                Harry's Rail
# 7                    Harry's Rail  Green Slab      The Killing Floor Left
# 8          The Killing Floor Left  Green Slab                  The Sickle
# 9                      The Sickle  Green Slab                     Big Boy
# 10                        Big Boy  Green Slab                  Real World
# 11                     Real World  Green Slab               Swank Stretch
# 12                  Swank Stretch  Green Slab                  Lounge Act
# 13                     Lounge Act  Green Slab                    Latch On
# 14           Can't Do It In Shoes  Green Slab                Gastonomical
# 15                   Gastonomical  Green Slab                Sloppy Poppy
# 16                   Sloppy Poppy  Green Slab                      Galaxy
# 17                         Galaxy  Green Slab              Detached Flake
# 18                 Detached Flake  Green Slab                  Flow Stone
# 19                   Space Monkey  Green Slab              Ride the Waves
# 20                 Ride the Waves  Green Slab   The Land That Time Forgot
# 21      The Land That Time Forgot  Green Slab               Cradle Robber
# 22                  Cradle Robber  Green Slab        A Tribe Called Quest
# 23           A Tribe Called Quest  Green Slab      Creekside Mega Problem
# 24         Creekside Mega Problem  Green Slab              Speech Therapy
# 25                 Speech Therapy  Green Slab             The Golden Bowl
# 26                The Golden Bowl  Green Slab          Swami of the Creek
# 27             Swami of the Creek  Green Slab          Flake Traverse Low
# 28             Flake Traverse Low  Green Slab                  Mindbender
# 29                     Mindbender  Green Slab                 Centre Slab
# 30                    Centre Slab  Green Slab                        Boat
# 31                           Boat  Green Slab                  Palminator
# 32                     Palminator  Green Slab      Super Daddy Long Limbs
# 33         Super Daddy Long Limbs  Green Slab                 Words of Me
# 34                    Words of Me  Green Slab          Spotters on Strike
# 35             Spotters on Strike  Green Slab                        Hewy
# 36                           Hewy  Green Slab                        Lewy
# 37                           Dewy  Green Slab             American Gigolo
# 38                American Gigolo  Green Slab              Tea Bag Undies
# 39                 Tea Bag Undies  Green Slab                 Middle cave
# 40                    Middle cave  Green Slab                     Acetone
# 41                        Acetone  Green Slab            The Boss's Crack
# 42               The Boss's Crack  Green Slab                  Prow Right
# 43                     Prow Right  Green Slab       Easy In An Easy Chair
# 44          Easy In An Easy Chair  Green Slab                   Superdyke
# 45                      Superdyke  Green Slab              Squealing Pork
# 46                 Squealing Pork  Green Slab                   Sali Bong
# 47                      Sali Bong  Green Slab              Lie Back Crack
# 48                 Lie Back Crack  Green Slab               Finger of God
# 49                          Alien  Green Slab                 Faceburster
# 50  All Aboard the Swaize Express  Green Slab                   Rib Rider
# 51                      Rib Rider  Green Slab            Back Door Bandit
# 52               Back Door Bandit  Green Slab                   Surf's Up
# 53                      Surf's Up  Green Slab                  Surf Arete
# 54                     Surf Arete  Green Slab                In Your Face
# 55                   In Your Face  Green Slab           French Connection
# 56              French Connection  Green Slab                   The Crimp
# 57                      The Crimp  Green Slab               Littlest Hobo
# 58                  Littlest Hobo  Green Slab                      Peeler
# 59                         Peeler  Green Slab                 Hummingbird
# 60                    Hummingbird  Green Slab               Killa Gorilla
# 61                  Killa Gorilla  Green Slab                 Tai Fighter
# 62                  Little Dragon  Green Slab                   Prow Left
# 63                      Prow Left  Green Slab          Practical Horseman
# 64             Practical Horseman  Green Slab                       Re-up
# 65                          Re-up  Green Slab                    Left Rib
# 66                       Left Rib  Green Slab                       Drone
# 67                          Drone  Green Slab       Sloppy Poppy Traverse
# 68          Sloppy Poppy Traverse  Green Slab                  Black Mark
# 69                Airtight Garage  Green Slab                 Shots Fired
# 70                   The Silencer  Green Slab            Loki Shoots Fire
# 71               Loki Shoots Fire  Green Slab                    Superfly
# 72                       Superfly  Green Slab              Superfly Lunge
# 73                 Superfly Lunge  Green Slab                   Hip Check
# 74                      Hip Check  Green Slab                  Golden Boy
# 75                     Golden Boy  Green Slab                         911
# 76                          The I  Green Slab  Backwards in an Easy Chair
# 77                     The Tugger  Green Slab                What a Beaut
# 78                   What a Beaut  Green Slab           How Neat is That?
# 79              How Neat is That?  Green Slab            What a Beaut Low
# 80               What a Beaut Low  Green Slab                    Aquarium
# 81                       Aquarium  Green Slab               Lanky Horvath
# 82                  Lanky Horvath  Green Slab                   Fish Tank
# 83                     Shark Tank  Green Slab                   Albatross
# 84                      Albatross  Green Slab        Tim's Sloper Problem
# 85           Tim's Sloper Problem  Green Slab                    Dr. Evil
# 86                       Dr. Evil  Green Slab              Mantel Madness
# 87                 Mantel Madness  Green Slab                   El Camino
# 88                      El Camino  Green Slab           Conspiracy of One
# 89              Conspiracy of One  Green Slab                   The Touch
#
#      11                                     12   13
# 0   V5+                       Missing Reaction   V7
# 1   V6+                           Driven Stand   V9
# 2   V3+                        Quinn's Problem   V4
# 3   V0-                        Aretes For Days   V0
# 4   V1-                        Scratching Post   V1
# 5   V3-                                Titanic  V3+
# 6    V1                           Sunset Crack   V1
# 7   V1-                          Born Too Slow  V2+
# 8   V3+                           Alien Within   V3
# 9    V4                      Lipsmack traverse  V4-
# 10   V3                                Titanic  V3+
# 11   V5                                 Galaxy   V5
# 12   V6                           Minor Threat   V6
# 13   V3                          Double Decker   V3
# 14   V5                         Into The Light  V5-
# 15   V4                            Trad Killer   V4
# 16   V5                                  Viper   V5
# 17  V0+                        Summer Vacation  V0-
# 18  V4-                           Space Monkey   V5
# 19   V7                               The Fuzz   V7
# 20  V6+                              Ramen Raw   V7
# 21  V7+                                Tatonka  V9-
# 22   V4                            Shots Fired   V4
# 23  V7-                             Mindbender   V7
# 24   V3  Bert and Ernie Were Just Good Friends  V3+
# 25   V6                           Minor Threat   V6
# 26   V4                                  Doubt  V5+
# 27   V6                            Evil Empire   V6
# 28   V7                              Ramen Raw   V7
# 29   V3                            Stupid Face   V3
# 30   V5                              Diabolica   V5
# 31   V4                             Skin Graft   V4
# 32   V6                            Hummingbird   V6
# 33  V9-                              Immunized  V8+
# 34  V0-                          Superfly Slab  V0-
# 35  V1-                 Squamish Days Traverse  V1+
# 36  V2-                                   Dewy   V2
# 37   V3                                   Dewy   V2
# 38   V4                           Sloppy Poppy   V4
# 39   V5                                  Viper   V5
# 40  V7+                          Pyramid Arete   V6
# 41   V1                            White Bread  V1+
# 42   V7                       Back Door Bandit   V5
# 43   V4                       Handible Lecture   V4
# 44   V3                           Alien Within   V3
# 45   V7                             Mindbender   V7
# 46   V7                         Storm Troopers   V8
# 47   V0                              Dumb Slab  V0-
# 48   V1                       The Warm Up Cave   V1
# 49   V4          All Aboard the Swaize Express  V5-
# 50   V3                                Titanic  V3+
# 51   V5                     Swami of the Creek   V4
# 52   V5                     Swami of the Creek   V4
# 53  V7+                    Empire Strikes Back  V8-
# 54   V3                 The Casualty Collector   V3
# 55  V5-                    Cave Dweller Center  V4-
# 56   V5                    Prime Time Sit-down   V5
# 57   V5                         Peelin' Monkey  V5+
# 58   V4                    Prime Time Sit-down   V5
# 59   V6                           Change Agent   V6
# 60  V7+                       Mr. Bigglesworth  V7+
# 61   V4                            Shots Fired   V4
# 62   V6                          Little Dragon  V6+
# 63   V4                          Swank Stretch   V5
# 64   V5                          Swank Stretch   V5
# 65   V2                               Hydrogen   V2
# 66  V3+                            ChossABlock  V2-
# 67  V5-                          Depths Direct  V4+
# 68  V4-                     Practical Horseman   V4
# 69   V4                            Trad Killer   V4
# 70   V6                          Swank Stretch   V5
# 71   V4                             Skin Graft   V4
# 72  V4-                  Easy In An Easy Chair   V4
# 73  V6-                           Minor Threat   V6
# 74   V7                               The Fuzz   V7
# 75   V3                          Double Decker   V3
# 76  V4-                              Green Tea   V4
# 77   V4                                FAROUK!  V3+
# 78  V4-                                  Re-up   V5
# 79  V6-                       Tyler's Traverse   V5
# 80   V2                               Paperboy   V2
# 81  V3-                              Fish Tank  V3-
# 82  V3-                       Propane, Propane   V4
# 83   V3                               Dog Days   V3
# 84   V5                            Angel Wings  V5-
# 85   V5                            Middle cave   V5
# 86   V4                            Child Abuse   V4
# 87  V8-                               Autobody   V8
# 88   V6                                  Viper   V5
# 89  V9-                                Tatonka  V9-

# %%
wrong_ids = np.unique(finn_p[finn_p!=finn_y])
wrong_ids
# Out:
# array([   3,   24,   31,   38,   48,   58,   72,   85,   86,   93,   97,
#          98,   99,  100,  102,  103,  125,  131,  134,  138,  142,  146,
#         147,  158,  163,  169,  174,  225,  268,  275,  323,  327,  347,
#         355,  409,  410,  418,  424,  425,  454,  458,  463,  549,  550,
#         579,  671,  697,  703,  753,  817,  885, 1014, 1051, 1149, 1167,
#        1188, 1262, 1317, 1320, 1345, 1401, 1477, 1524, 1579, 1794, 1836,
#        2045, 2313, 2743, 2756], dtype=int32)

# %%
wrong_ids = np.unique(finn_p[finn_p!=finn_y])
print(len(wrong_ids[~np.isin(wrong_ids, features['climb_token'].loc['finnfrasergrathwol'])])/len(wrong_ids))
bc_boulders_5.loc[inverse_vocabulary.loc[wrong_ids[~np.isin(wrong_ids, features['climb_token'].loc['finnfrasergrathwol'])]].values]['name'].tolist()
# Out:
# 0.7142857142857143
# ['Squamish Days Traverse',
#  'Alien Within',
#  'Double Decker',
#  'Child Abuse',
#  'Tatonka',
#  'The Fuzz',
#  'Depths Direct',
#  'Viper',
#  'Titanic',
#  'Storm Troopers',
#  'Ramen Raw',
#  'Missing Reaction',
#  'Diabolica',
#  "Tyler's Traverse",
#  'Paperboy',
#  'Skin Graft',
#  'Summer Vacation',
#  'Into The Light',
#  'Mr. Bigglesworth',
#  'ChossABlock',
#  'Superfly Slab',
#  'Born Too Slow',
#  'Pyramid Arete',
#  'Prime Time Sit-down',
#  'Bert and Ernie Were Just Good Friends',
#  'White Bread',
#  'Hydrogen',
#  'Minor Threat',
#  'Doubt',
#  'Green Tea',
#  'Immunized',
#  'Autobody',
#  "Peelin' Monkey",
#  'Lipsmack traverse',
#  'Dog Days',
#  'Handible Lecture',
#  'Evil Empire',
#  'Cave Dweller Center',
#  'Scratching Post',
#  "Quinn's Problem",
#  'Empire Strikes Back',
#  'Angel Wings',
#  'FAROUK!',
#  'Stupid Face',
#  'Change Agent',
#  'Sunset Crack',
#  'The Warm Up Cave',
#  'Driven Stand',
#  'The Casualty Collector',
#  'Aretes For Days']

# %% [markdown]
# ## Explore Embeddings Space

# %%
def cosine(v, m):
    # dot(a, b)/(norm(a)*norm(b))
    norm_v = np.sqrt(np.sum(v**2))
    norms_m = np.sqrt(np.sum(embeddings**2, axis=1))
    return np.squeeze(np.dot(v[np.newaxis, :], m.T) / norm_v / norms_m)

# %%
def l2(v, m):
    return np.sqrt(np.sum((v[np.newaxis, :] - m)**2, axis=1))

# %%
params['params']['Embed_0']['embedding'].shape
# Out:
# (3014, 100)

# %%
embeddings = np.array(best_params['params']['Embed_0']['embedding'])

# %%
queries = ['Superfly', 'Pocket Problem', 'Trad Killer']
climb_ids = [bc_boulders_5[bc_boulders_5['name']==query].index[0] for query in queries]
q_tokens = vocabulary.loc[climb_ids].values
embeddings[q_tokens, :].shape
# Out:
# (3, 100)

# %%
q_tokens
# Out:
# array([106,  43,  72])

# %%
bc_boulders_5.loc[inverse_vocabulary.loc[np.argsort(cosine(embeddings[q_tokens[0], :], 
                                                       embeddings))[-10:-1]]]
# Out:
#                                                        slug  \
# climb_id
# 75565     killing-floor-left-jungle-apron-boulders-squam...
# 98891     lick-gonzos-finger-poultry-boulder-area-giscom...
# 119066       belly-flop-left-sandy-cove-vancouver-bc-canada
# 79629     oxygen-clean-boulders-north-walls-squamish-bc-...
# 99927     black-mark-dyno-thighmaster-grand-wall-boulder...
# 133986    easter-island-public-works-godman-creek-vancou...
# 92507     death-cookies-grand-wall-boulders-squamish-bc-...
# 73394     shakedown-sit-down-grand-wall-boulders-squamis...
# 97046     catch-that-cat-grand-wall-boulders-squamish-bc...
#
#                             name  area_id     type  grade_id  bolts  length  \
# climb_id
# 75565     The Killing Floor Left     8709  boulder        13      0     NaN
# 98891        Lick Gonzo's Finger     5427  boulder        18      0     NaN
# 119066           Belly Flop Left     8284  boulder        22      0     NaN
# 79629                     oxygen     6433  boulder        22      0     NaN
# 99927            Black Mark Dyno     7972  boulder        22      0     NaN
# 133986             Easter Island    10095  boulder        14      0     NaN
# 92507              Death Cookies     4778  boulder        22      0     NaN
# 73394         Shakedown Sit Down     4778  boulder        41      0     NaN
# 97046             Catch That Cat     4778  boulder        21      0     NaN
#
#          grade                                        description  # onsights  \
# climb_id
# 75565      V1-                                                              3
# 98891       V2                                                              0
# 119066      V3                                                              0
# 79629       V3                                                              2
# 99927       V3                                                              1
# 133986      V1  Climb the opposing arêtes, high-stepping above...           2
# 92507       V3                                                              1
# 73394       V6                                                              0
# 97046      V3-                                                              1
#
#           # redpoint  # flashes  # sends areas_0_name         areas_1_name  \
# climb_id
# 75565             13          5       21     Squamish       Apron Boulders
# 98891              0          5        5       Canada     British Columbia
# 119066             5          1        6    Vancouver           Sandy Cove
# 79629              2          3        7     Squamish          North Walls
# 99927              9          2       12     Squamish  Grand Wall Boulders
# 133986             1          2        5    Vancouver         Godman Creek
# 92507              3          1        5     Squamish  Grand Wall Boulders
# 73394             13          1       14     Squamish  Grand Wall Boulders
# 97046              4          0        5     Squamish  Grand Wall Boulders
#
#                 areas_2_name         areas_0_slug  \
# climb_id
# 75565             The Jungle   squamish-bc-canada
# 98891          Prince George               canada
# 119066                        vancouver-bc-canada
# 79629     The Clean Boulders   squamish-bc-canada
# 99927            Thighmaster   squamish-bc-canada
# 133986          Public Works  vancouver-bc-canada
# 92507                          squamish-bc-canada
# 73394                          squamish-bc-canada
# 97046                          squamish-bc-canada
#
#                                     areas_1_slug  \
# climb_id
# 75565          apron-boulders-squamish-bc-canada
# 98891                                  bc-canada
# 119066            sandy-cove-vancouver-bc-canada
# 79629             north-walls-squamish-bc-canada
# 99927     grand-wall-boulders-squamish-bc-canada
# 133986          godman-creek-vancouver-bc-canada
# 92507     grand-wall-boulders-squamish-bc-canada
# 73394     grand-wall-boulders-squamish-bc-canada
# 97046     grand-wall-boulders-squamish-bc-canada
#
#                                                areas_2_slug      areas_3_name  \
# climb_id
# 75565              jungle-apron-boulders-squamish-bc-canada
# 98891                               prince-george-bc-canada  Giscome Boulders
# 119066
# 79629         clean-boulders-north-walls-squamish-bc-canada
# 99927     thighmaster-grand-wall-boulders-squamish-bc-ca...
# 133986        public-works-godman-creek-vancouver-bc-canada
# 92507
# 73394
# 97046
#
#                                       areas_3_slug          areas_4_name  \
# climb_id
# 75565                                                                NaN
# 98891     giscome-boulders-prince-george-bc-canada  Poultry Boulder Area
# 119066                                                               NaN
# 79629                                                                NaN
# 99927                                                                NaN
# 133986                                                               NaN
# 92507                                                                NaN
# 73394                                                                NaN
# 97046                                                                NaN
#
#                                                areas_4_slug areas_5_name  \
# climb_id
# 75565                                                   NaN          NaN
# 98891     poultry-boulder-area-giscome-boulders-prince-g...          NaN
# 119066                                                  NaN          NaN
# 79629                                                   NaN          NaN
# 99927                                                   NaN          NaN
# 133986                                                  NaN          NaN
# 92507                                                   NaN          NaN
# 73394                                                   NaN          NaN
# 97046                                                   NaN          NaN
#
#          areas_5_slug areas_6_name areas_6_slug areas_7_name areas_7_slug  \
# climb_id
# 75565             NaN          NaN          NaN          NaN          NaN
# 98891             NaN          NaN          NaN          NaN          NaN
# 119066            NaN          NaN          NaN          NaN          NaN
# 79629             NaN          NaN          NaN          NaN          NaN
# 99927             NaN          NaN          NaN          NaN          NaN
# 133986            NaN          NaN          NaN          NaN          NaN
# 92507             NaN          NaN          NaN          NaN          NaN
# 73394             NaN          NaN          NaN          NaN          NaN
# 97046             NaN          NaN          NaN          NaN          NaN
#
#          areas_8_name areas_8_slug areas_9_name areas_9_slug areas_10_name  \
# climb_id
# 75565             NaN          NaN          NaN          NaN           NaN
# 98891             NaN          NaN          NaN          NaN           NaN
# 119066            NaN          NaN          NaN          NaN           NaN
# 79629             NaN          NaN          NaN          NaN           NaN
# 99927             NaN          NaN          NaN          NaN           NaN
# 133986            NaN          NaN          NaN          NaN           NaN
# 92507             NaN          NaN          NaN          NaN           NaN
# 73394             NaN          NaN          NaN          NaN           NaN
# 97046             NaN          NaN          NaN          NaN           NaN
#
#          areas_11_name areas_10_slug areas_11_slug  ratings_min  ratings_max  \
# climb_id
# 75565              NaN           NaN           NaN          2.0          4.0
# 98891              NaN           NaN           NaN          2.0          4.0
# 119066             NaN           NaN           NaN          2.0          4.0
# 79629              NaN           NaN           NaN          2.0          5.0
# 99927              NaN           NaN           NaN          1.0          5.0
# 133986             NaN           NaN           NaN          5.0          5.0
# 92507              NaN           NaN           NaN          1.0          1.0
# 73394              NaN           NaN           NaN          2.0          4.0
# 97046              NaN           NaN           NaN          2.0          3.0
#
#           ratings_mean  ratings_count  stars_isna  connected V grade  onsight  \
# climb_id
# 75565         2.923077           13.0         8.0       True    0.75        3
# 98891         3.000000            5.0         0.0       True       2        0
# 119066        3.000000            4.0         2.0       True       3        0
# 79629         3.500000            6.0         1.0       True       3        2
# 99927         3.111111            9.0         3.0       True       3        1
# 133986        5.000000            5.0         0.0       True       1        2
# 92507         1.000000            4.0         1.0       True       3        1
# 73394         3.000000           11.0         3.0       True       6        0
# 97046         2.250000            4.0         1.0       True    2.75        1
#
#           flash  redpoint
# climb_id
# 75565         5        13
# 98891         5         0
# 119066        1         5
# 79629         3         2
# 99927         2         9
# 133986        2         1
# 92507         1         3
# 73394         1        13
# 97046         0         4

# %%
cosine(embeddings[q_tokens[0], :],  embeddings).shape
# Out:
# (3014,)
